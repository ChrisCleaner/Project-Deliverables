# %% [markdown]
# # Retrieve Meta Data from Treaties

# %%
#import packages
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
import pdftotext
import docx2txt
from os import listdir
import fuzzyset
import time
import difflib
import regex as re
import os
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity 
from fuzzywuzzy import fuzz

#get the meta data - webscraped and saved as csv file
df_meta_treaty = pd.read_csv("Meta Data Treaties.csv")
df_meta_treaty_decision = pd.read_csv("Meta Data Treaty Decisions.csv")

#create list with all treaty names / These names in the list will be searched later
treaty_names = list(df_meta_treaty["Title"])

#delete fill words
for number, treaty in enumerate(treaty_names):
    new_name = ""
    for word in treaty.split():
        if (word.lower() in stopwords.words("english")) or (word.lower() in stopwords.words("spanish")): #some documents are spanish
            pass
        else:
            new_name += (word + " ")
    treaty_names[number] = new_name[:-1]

# %% [markdown]
# # Analyze Text

# %%
"""
GOES THROUGH THE TRAIN DATA WITH DIFFERENT ASSESSMENT METHODS
PRINTS TIME NEEDED AND THE FOUND TREATY DECISIONS WITH ASSOCIATED VALUES
DICT_OF_CORRECT_ANSWERS PROVIDES CORRECT ANSWERS MANUALLY SEARCHED BY CHRISTOPH KRUEGER
"""

list_of_subfolders = ["Train Data"] #can be extended, but only use one small folder for now

#create a dictionary with the right answers, to later check the accuracy of the algorithms
dict_of_correct_answers = {}
dict_of_correct_answers['Management of Marine Debris.txt'] = ['International Convention for the Prevention of Pollution From Ships','Convention on Biological Diversity', 'London Convention','Inter American Convention for the Protection and Conservation of Sea Turtles','Protocols to Regional Seas Conventions on Pollution from Land Based Sources']
dict_of_correct_answers['A paration for the followup to the Strategic Plan for Biodiversity 20112020 and the Strategic Plan for the Cartagena Protocol on Biosafety 20112020.pdf.txt'] = ['Convention on Biological Diversity','Cartagena Protocol on Biosafety', 'Nagoya – Kuala Lumpur Supplementary Protocol']
dict_of_correct_answers['African cherry Prunus africana.txt'] = ['None']
dict_of_correct_answers['COP411 Cooperation with the European Union.txt'] = ['None']
dict_of_correct_answers['Environmental assessmentinformation system, monitoring and early warning xe2x80x93 Article 12 of the Carpathian Convention.txt'] = ['None'] #should reference Carpathian Convention, but the convention is not in ecolex
dict_of_correct_answers['Hexachlorobutadiene.txt'] = ['Stockholm Convention']
dict_of_correct_answers['Outcome of the UNCCD 1st Scientific Conference.pdf.txt'] = ['None']
dict_of_correct_answers['Preparation for the followup to the Strategic Plan for Biodiversity 20112020.pdf.txt'] = ['Convention on Biological Diversity', 'NAGOYA PROTOCOL ON ACCESS TO GENETIC RESOURCES', 'NAGOYA PROTOCOL ON ACCESS AND BENEFIT-SHARING'] 
dict_of_correct_answers['Process for aligning national reporting, assessment and review.pdf.txt'] = ['Convention on Biological Diversity', 'Rio conventions', 'Cartagena Protocol', 'Nagoya Protocol'] 
dict_of_correct_answers['Pyu Ancient Cities Myanmar C 1444.txt'] = ['None']
dict_of_correct_answers['Review of annexes A and B.pdf.txt'] = ['Minamata Convention on Mercury']
dict_of_correct_answers['Submission regarding Swaziland.txt'] = ['Basel Convention'] #ecolex name differs widely



#retrieve the best n names with their values frmo two lists
def find_top_X(values, names, n = 5):
    top_idx = np.argsort(values)[-n:]
    top_vals = [values[i] for i in top_idx]
    top_names = [names[i] for i in top_idx]
    return top_vals[::-1], top_names[::-1]



def create_tfidf_features(corpus, max_features=20000, max_df=0.95, min_df=2):
    #concept idea for the algorithm from https://github.com/sci2lab/ml_tutorial/blob/master/ml_tutorial/tfidf.py#L24
    """ Creates a tf-idf matrix for the `corpus` using sklearn. """
    tfidf_vectorizor = TfidfVectorizer(decode_error='replace', strip_accents='unicode', analyzer='word',
                                       stop_words='english', ngram_range=(1, 4), max_features=max_features,
                                       norm='l2', use_idf=True, smooth_idf=True, sublinear_tf=True, vocabulary = None) #or use vocab treaty dict
    X = tfidf_vectorizor.fit_transform(corpus)
    print('tfidf matrix successfully created.')
    return X, tfidf_vectorizor

def preprocess(title, body=None):
    #concept idea for the algorithm from https://github.com/sci2lab/ml_tutorial/blob/master/ml_tutorial/tfidf.py#L24
    """ Preprocess the input, i.e. lowercase, remove html tags, special character and digits."""
    text = ''
    if body is None:
        text = title
    else:
        text = title + body
    # to lower case
    text = text.lower()

    # remove tags
    text = re.sub("</?.*?>"," <> ", text)

    # remove special characters and digits
    text = re.sub("(\\d|\\W)+"," ", text).strip()
    return text

def calculate_similarity(X, vectorizor, queries, top_k=5):
    #concept idea for the algorithm from https://github.com/sci2lab/ml_tutorial/blob/master/ml_tutorial/tfidf.py#L24
    """ Vectorizes the `query` via `vectorizor` and calculates the cosine similarity of
    the `query` and `X` (all the documents) and returns the `top_k` similar documents."""

    # Vectorize the query to the same length as documents
    similarities = []
    for query in queries:
        query_vec = vectorizor.transform([query])
        # Compute the cosine similarity between query_vec and all the documents
        cosine_similarities = cosine_similarity(X,query_vec).flatten()
        similarities.append(cosine_similarities)
        
    return similarities




def text_mining(treaty_names):
    
    #create dataframes for later saving data
    df_fuzzysearch = pd.DataFrame(columns = treaty_names)
    df_sequencematch = pd.DataFrame(columns = treaty_names)
    
    
    for subfolder in list_of_subfolders: #loop over subfolders
        list_of_files = listdir("Downloads/" + subfolder) #get all files
        
        for filename in list_of_files: #go through files in subfolder
            
            if (filename[-3:] == "txt"):  #check if it is a txt document
                with open("Downloads/" + subfolder + "/" + filename, encoding = "utf8") as f:
                    document_text = f.readlines()
                    
                print(dict_of_correct_answers)
                #clean the document
                text = " ".join(document_text) #create long string 
                text = text.lower()
                text = re.sub("</?.*?>"," <> ", text) # remove tags
                text = re.sub("(\\d|\\W)+"," ", text).strip() # remove special characters and digits
                text = text.split()
                
                
                list_of_outcomes = []
                start_time = time.time() #to later see the speed of the programm
                
                '''
                VERSION 0: TF-IDF Matrix
                Super Quick, However, not very accurate so far
                '''


                X,v = create_tfidf_features([' '.join(text)])
                features = v.get_feature_names()



                search_start = time.time()
                similarities = calculate_similarity(X, v, treaty_names)
                search_time = time.time() - search_start
                list_sim = []
                for sim in similarities:
                    list_sim.append(float(sim))
                print("time TF-IDF: ", search_time)
                print(find_top_X(list_sim, treaty_names, 10))
                #loop over treaty names, to see if it is mention in the document text
                for treaty in treaty_names: 
                    
                    #treaty = "Nagoya Kuala Lumpur Supplementary Protocol Liability Redress Cartagena Protocol Biosafety"
                    
                    
                    
                    
                    '''
                    VERSION 1: Use fuzzy search
                    As fuzzysearch doesn't work well if the string length differ widely,
                    the code loops over different overlaping parts of the text and saves the highest score
                    '''
                    high_score = 0
                    name_len = len(treaty.split()) #see how long the treaty name is
                    for num  in range(0, len(text) - 2 - name_len, (name_len + 2) // 2): #get the length of the text and get a step size that is according to the name length
                        
                        #use fuzzy search to see the match for the specific part of the text
                        Search_Query = fuzzyset.FuzzySet()
                        Search_Query.add(treaty)
                        outcome = Search_Query.get("".join(text[num:num + name_len + 2]))
                        
                        
                        if outcome != None: #check if the match is None (None will cause error)
                            if outcome[0][0] > high_score: #check if the current score is larger than the highest score
                                high_score = outcome[0][0] #update highscore
                    list_of_outcomes.append(high_score)
                
                #add outcomes to df, save df
                df_fuzzysearch.loc[filename[-3:]] = list_of_outcomes
                df_fuzzysearch.to_csv('Downloads/Fuzzy Search Outcomes.csv')
                print('time FuzzySearch: ', time.time() - start_time)
                print(find_top_X(list_of_outcomes, treaty_names, 10))
                
                #print closes match
                #print(filename, ' Match: ', treaty_names[list_of_outcomes.index(max(list_of_outcomes))], (max(list_of_outcomes)))
                
                    
                list_of_outcomes = []
                start_time = time.time()
                for treaty in treaty_names: 
                    '''
                    VERSION 2: SequenceMatcher
                    Different library - roughly three times faster
                    does not need to loop over 
                    Currently very inaccurate
                    '''
                    
                    
                    s = difflib.SequenceMatcher(None, ' '.join(text), treaty)
                    high_score = sum(n for i,j,n in s.get_matching_blocks()) / float(len(treaty))
                    list_of_outcomes.append(high_score)
                    
                #add outcomes to df, save df
                print('time SequenceMatcher: ', time.time() - start_time)
                print(find_top_X(list_of_outcomes, treaty_names, 10))
                df_sequencematch.loc[filename[-3:]] = list_of_outcomes
                df_sequencematch.to_csv('Downloads/Seqeunce Match Outcomes.csv')
                
                
                
                list_of_outcomes = []
                start_time = time.time()
                for treaty in treaty_names: 
                    '''
                    VERSION 3: FuzzyWuzzy
                    Similarly quick as fuzzysearch, but less accurate
                    '''
                    
                    
                    highscore = fuzz.ratio(" ".join(text), treaty)
                    list_of_outcomes.append(high_score/100)
                    
                #add outcomes to df, save df
                print('time SequenceMatcher: ', time.time() - start_time)
                print(find_top_X(list_of_outcomes, treaty_names, 10))
                df_sequencematch.loc[filename[-3:]] = list_of_outcomes
                df_sequencematch.to_csv('Downloads/Seqeunce Match Outcomes.csv')

                
            
                
    
text_mining(treaty_names)
print("ENDE")
# Out:
# {'Management of Marine Debris.txt': ['International Convention for the Prevention of Pollution From Ships', 'Convention on Biological Diversity', 'London Convention', 'Inter American Convention for the Protection and Conservation of Sea Turtles', 'Protocols to Regional Seas Conventions on Pollution from Land Based Sources'], 'A paration for the followup to the Strategic Plan for Biodiversity 20112020 and the Strategic Plan for the Cartagena Protocol on Biosafety 20112020.pdf.txt': ['Convention on Biological Diversity', 'Cartagena Protocol on Biosafety', 'Nagoya – Kuala Lumpur Supplementary Protocol'], 'African cherry Prunus africana.txt': ['None'], 'COP411 Cooperation with the European Union.txt': ['None'], 'Environmental assessmentinformation system, monitoring and early warning xe2x80x93 Article 12 of the Carpathian Convention.txt': ['None'], 'Hexachlorobutadiene.txt': ['Stockholm Convention'], 'Outcome of the UNCCD 1st Scientific Conference.pdf.txt': ['None'], 'Preparation for the followup to the Strategic Plan for Biodiversity 20112020.pdf.txt': ['Convention on Biological Diversity', 'NAGOYA PROTOCOL ON ACCESS TO GENETIC RESOURCES', 'NAGOYA PROTOCOL ON ACCESS AND BENEFIT-SHARING'], 'Process for aligning national reporting, assessment and review.pdf.txt': ['Convention on Biological Diversity', 'Rio conventions', 'Cartagena Protocol', 'Nagoya Protocol'], 'Pyu Ancient Cities Myanmar C 1444.txt': ['None'], 'Review of annexes A and B.pdf.txt': ['Minamata Convention on Mercury'], 'Submission regarding Swaziland.txt': ['Basel Convention']}
# tfidf matrix successfully created.
# time TF-IDF:  4.288866281509399
# ([0.2671125351183198, 0.17852596239050794, 0.11812622109764166, 0.11642103921538015, 0.11642103921538015, 0.11546515452589383, 0.11546515452589383, 0.11546515452589383, 0.11265772277923669, 0.11265772277923669], ['Nagoya Kuala Lumpur Supplementary Protocol Liability Redress Cartagena Protocol Biosafety', 'Cartagena Protocol Biosafety Convention Biological Diversity', 'Protocol implementation Alpine Convention field town country planning sustainable development', 'Protocol Implementation SenegaloGambian Agreement Field Maritime Fisheries', 'Agreement LongTerm Economic, Cultural, Scientific, Technical Industrial Cooperation Government Republic Cyprus Government Republic Rwanda Protocol implementation Agreement', 'Protocol Sustainable Forest Management Framework Convention Protection Sustainable Development Carpathians', 'Protocol Sustainable Tourism Framework Convention Protection Sustainable Development Carpathians', 'Protocol Sustainable Transport Framework Convention Protection Sustainable Development Carpathians', 'Additional Protocol Framework agreement environment MERCOSUR', 'Protocol claims, legal proceedings indemnification framework agreement multilateral nuclear environmental programme Russian Federation'])
# time FuzzySearch:  290.79698395729065
# ([0.736842105263158, 0.631578947368421, 0.6292134831460674, 0.6, 0.5555555555555556, 0.5555555555555556, 0.5555555555555556, 0.5384615384615384, 0.52, 0.46875], ['Convention Biological Diversity', 'Protocol Fisheries', 'Nagoya Kuala Lumpur Supplementary Protocol Liability Redress Cartagena Protocol Biosafety', 'Cartagena Protocol Biosafety Convention Biological Diversity', 'Protocol Energy', 'Protocol Forestry', 'Protocol Mining', 'Food Assistance Convention', 'Third ACPCEE Convention', 'Doha Amendment Kyoto Protocol'])
# time SequenceMatcher:  151.41999077796936
# ([0.953125, 0.9078947368421053, 0.9069767441860465, 0.9066666666666666, 0.90625, 0.9032258064516129, 0.9024390243902439, 0.9019607843137255, 0.8979591836734694, 0.8936170212765957], ['Protocol implementation Alpine Convention field mountain forests', 'Convention civil liability damage resulting activities dangerous environment', 'Agreement plant protection Hungary Slovakia', 'Convention France Spain delimitation territorial contiguous zone Bay Biscay', 'Agreement Russian Federation Turkmenistan cooperation gas sector', 'Convention Biological Diversity', 'Convention Conservation Management Vicuna', 'Accord concernant lexportation vins italiens Suisse', 'Convention concerning supply water Commune Menton', 'Agreement Council Ministers Albania Government Romania collaboration sanitary veterinary field'])
# time SequenceMatcher:  4.268505811691284
# ([0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285], ['Revised Convention Navigation Rhine', 'Protocol implementation Alpine Convention 1991 field energy', 'Agreement Government Russian Federation Portugal cooperation sphere civil protection, prevention mitigation emergency situations', 'Agreement Government Russian Federation Government Kazakhstan scientific technical cooperation realization experimental thermonuclear reactor', 'Northwest Wildland Fire Protection Agreement', 'Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Agreement form Exchange Letters concerning provisional application Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Protocol implementation Alpine Convention 1991 field tourism', 'Protocol Implementation 1991 Alpine Convention Soil Protection', 'Kyoto Protocol United Nations Framework Convention Climate Change'])
# {'Management of Marine Debris.txt': ['International Convention for the Prevention of Pollution From Ships', 'Convention on Biological Diversity', 'London Convention', 'Inter American Convention for the Protection and Conservation of Sea Turtles', 'Protocols to Regional Seas Conventions on Pollution from Land Based Sources'], 'A paration for the followup to the Strategic Plan for Biodiversity 20112020 and the Strategic Plan for the Cartagena Protocol on Biosafety 20112020.pdf.txt': ['Convention on Biological Diversity', 'Cartagena Protocol on Biosafety', 'Nagoya – Kuala Lumpur Supplementary Protocol'], 'African cherry Prunus africana.txt': ['None'], 'COP411 Cooperation with the European Union.txt': ['None'], 'Environmental assessmentinformation system, monitoring and early warning xe2x80x93 Article 12 of the Carpathian Convention.txt': ['None'], 'Hexachlorobutadiene.txt': ['Stockholm Convention'], 'Outcome of the UNCCD 1st Scientific Conference.pdf.txt': ['None'], 'Preparation for the followup to the Strategic Plan for Biodiversity 20112020.pdf.txt': ['Convention on Biological Diversity', 'NAGOYA PROTOCOL ON ACCESS TO GENETIC RESOURCES', 'NAGOYA PROTOCOL ON ACCESS AND BENEFIT-SHARING'], 'Process for aligning national reporting, assessment and review.pdf.txt': ['Convention on Biological Diversity', 'Rio conventions', 'Cartagena Protocol', 'Nagoya Protocol'], 'Pyu Ancient Cities Myanmar C 1444.txt': ['None'], 'Review of annexes A and B.pdf.txt': ['Minamata Convention on Mercury'], 'Submission regarding Swaziland.txt': ['Basel Convention']}
# tfidf matrix successfully created.
# time TF-IDF:  4.420001029968262
# ([0.15724501141601577, 0.15724501141601577, 0.1549626172891157, 0.13946943633048223, 0.13470610100839508, 0.13470610100839508, 0.13470610100839508, 0.13470610100839508, 0.13470610100839508, 0.13470610100839508], ['International Tropical Timber Agreement, 1994', 'International Tropical Timber Agreement 2006', 'International Convention Control Harmful AntiFouling Systems Ships', 'Minute 291 International Boundary Water Commission United States Mexico concerning improvement conveying capacity international boundary segment Colorado River', 'Convention International Trade Endangered Species Wild Fauna Flora', 'Amendment Convention International Trade Endangered Species Wild Fauna Flora ArtXI', 'Resolution heads states Central Asia approval Statute International Aral Fund agreement status IASF organizations', 'Amendment Convention International Trade Endangered Species Wild Fauna Flora Art XXI', 'International Agreement US Department Interior, Bureau Land Management, US Department Agriculture, Forest Service National MultiAgency Coordination Group behalf Government United States America Secretary Department Natural Resources Environment agent Crown right Australian State Territory Crown right New Zealand', 'International Agreement US Department Interior, Bureau Land Management, US Department Agriculture, Forest Service National MultiAgency Coordination Group behalf Government United States America Secretary Department Natural Resources Environment agent Crown right Australian State Territory Crown right New Zealand'])
# time FuzzySearch:  44.97464561462402
# ([0.5510204081632653, 0.5510204081632653, 0.5434782608695652, 0.5294117647058824, 0.5, 0.5, 0.467741935483871, 0.4545454545454546, 0.44999999999999996, 0.4423076923076923], ['International Tropical Timber Agreement 2006', 'International Tropical Timber Agreement, 1994', 'Convention International Maritime Organization', 'International Convention Salvage', 'International Energy Charter', 'Constitution International Rice Commission', 'European Convention Protection Animals International Transport', 'Convention International Council Exploration', 'International Convention Safe Containers', 'Protocol International Convention Regulation Whaling'])
# time SequenceMatcher:  25.880484104156494
# ([0.8888888888888888, 0.8837209302325582, 0.8823529411764706, 0.8823529411764706, 0.8780487804878049, 0.8780487804878049, 0.875, 0.875, 0.8666666666666667, 0.8620689655172413], ['Protocol Fisheries', 'Agreement regarding Monitoring Stratosphere', 'Protocol Forestry', 'International agreement river Maas', 'International Convention Protection Birds', 'International Plant Protection Convention', 'International Convention Salvage', 'Antarctic Treaty', 'Protocol Mining', 'United Nations Convention Law'])
# time SequenceMatcher:  0.7665178775787354
# ([0.005714285714285714, 0.005714285714285714, 0.005714285714285714, 0.005714285714285714, 0.005714285714285714, 0.005714285714285714, 0.005714285714285714, 0.005714285714285714, 0.005714285714285714, 0.005714285714285714], ['Revised Convention Navigation Rhine', 'Protocol implementation Alpine Convention 1991 field energy', 'Agreement Government Russian Federation Portugal cooperation sphere civil protection, prevention mitigation emergency situations', 'Agreement Government Russian Federation Government Kazakhstan scientific technical cooperation realization experimental thermonuclear reactor', 'Northwest Wildland Fire Protection Agreement', 'Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Agreement form Exchange Letters concerning provisional application Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Protocol implementation Alpine Convention 1991 field tourism', 'Protocol Implementation 1991 Alpine Convention Soil Protection', 'Kyoto Protocol United Nations Framework Convention Climate Change'])
# {'Management of Marine Debris.txt': ['International Convention for the Prevention of Pollution From Ships', 'Convention on Biological Diversity', 'London Convention', 'Inter American Convention for the Protection and Conservation of Sea Turtles', 'Protocols to Regional Seas Conventions on Pollution from Land Based Sources'], 'A paration for the followup to the Strategic Plan for Biodiversity 20112020 and the Strategic Plan for the Cartagena Protocol on Biosafety 20112020.pdf.txt': ['Convention on Biological Diversity', 'Cartagena Protocol on Biosafety', 'Nagoya – Kuala Lumpur Supplementary Protocol'], 'African cherry Prunus africana.txt': ['None'], 'COP411 Cooperation with the European Union.txt': ['None'], 'Environmental assessmentinformation system, monitoring and early warning xe2x80x93 Article 12 of the Carpathian Convention.txt': ['None'], 'Hexachlorobutadiene.txt': ['Stockholm Convention'], 'Outcome of the UNCCD 1st Scientific Conference.pdf.txt': ['None'], 'Preparation for the followup to the Strategic Plan for Biodiversity 20112020.pdf.txt': ['Convention on Biological Diversity', 'NAGOYA PROTOCOL ON ACCESS TO GENETIC RESOURCES', 'NAGOYA PROTOCOL ON ACCESS AND BENEFIT-SHARING'], 'Process for aligning national reporting, assessment and review.pdf.txt': ['Convention on Biological Diversity', 'Rio conventions', 'Cartagena Protocol', 'Nagoya Protocol'], 'Pyu Ancient Cities Myanmar C 1444.txt': ['None'], 'Review of annexes A and B.pdf.txt': ['Minamata Convention on Mercury'], 'Submission regarding Swaziland.txt': ['Basel Convention']}
# tfidf matrix successfully created.
# time TF-IDF:  4.332729816436768
# ([0.2621042288714384, 0.2437954094517728, 0.2437954094517728, 0.2236348793007578, 0.2236348793007578, 0.2236348793007578, 0.21084091335974525, 0.20548997587718726, 0.20548997587718726, 0.20548997587718726], ['Agreement partnership cooperation Republic Kazakhstan European Union member countries', 'Agreement Government Russian Federation European Union cooperation sphere science technologies', 'Cooperation Agreement European Community Peoples Republic Bangladesh partnership development', 'Cooperation Agreement European Economic Community Swiss Confederation Research Development field wood, including cork, renewable raw material', 'Agreement Government Russian Federation European Space Agency cooperation partnership study outer space peaceful uses thereof', 'Agreement Government Russian Federation European space agency cooperation partnership sphere research management outer space peaceful purposes', 'Protocol Cypriot Republic European Union participation Cyprus European Environment Agency European Environment Information Observation Network N 5III2001', 'Agreement Canada European Atomic Energy Community cooperation area nuclear research', 'Agreement cooperation fisheries sector European Community Islamic Republic Mauritania', 'Agreement cooperation fisheries sector European Community Islamic Republic Mauritania'])
# time FuzzySearch:  27.211039781570435
# ([0.5277777777777778, 0.4838709677419355, 0.45238095238095233, 0.4482758620689655, 0.4358974358974359, 0.4222222222222223, 0.4130434782608695, 0.4117647058823529, 0.4, 0.4], ['Treaty Establishing Energy Community', 'Treaty Amazonian Cooperation', 'Agreement transboundary cooperation', 'Single European Act', 'Agreement establishing Pepper Community', 'General Agreement Cooperation Lebanon Gabon', 'Treaty Establishing African Economic Community', 'Agreement partnership cooperation Republic Kazakhstan European Union member countries', 'Convention Protection Rhine', 'Convention Nuclear Safety'])
# time SequenceMatcher:  15.502235889434814
# ([0.8529411764705882, 0.8275862068965517, 0.8235294117647058, 0.8076923076923077, 0.8059701492537313, 0.8, 0.7948717948717948, 0.7894736842105263, 0.7872340425531915, 0.782608695652174], ['International agreement river Maas', 'Regional Agreement transboundary movement hazardous wastes', 'Agreement establishment global crop diversity trust', 'Food Assistance Convention', 'Agreement establishing Southeast Asian Fisheries Development Center', 'Acuerdo materia sanidad animal', 'Convenio cooperacixc3xb3n fitosanitaria', 'CIS Agreement cooperation sphere timber industry forestry', 'Agreement Establishing South Pacific Commission', 'European Energy Charter'])
# time SequenceMatcher:  0.3996138572692871
# ([0.004857142857142857, 0.004857142857142857, 0.004857142857142857, 0.004857142857142857, 0.004857142857142857, 0.004857142857142857, 0.004857142857142857, 0.004857142857142857, 0.004857142857142857, 0.004857142857142857], ['Revised Convention Navigation Rhine', 'Protocol implementation Alpine Convention 1991 field energy', 'Agreement Government Russian Federation Portugal cooperation sphere civil protection, prevention mitigation emergency situations', 'Agreement Government Russian Federation Government Kazakhstan scientific technical cooperation realization experimental thermonuclear reactor', 'Northwest Wildland Fire Protection Agreement', 'Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Agreement form Exchange Letters concerning provisional application Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Protocol implementation Alpine Convention 1991 field tourism', 'Protocol Implementation 1991 Alpine Convention Soil Protection', 'Kyoto Protocol United Nations Framework Convention Climate Change'])
# {'Management of Marine Debris.txt': ['International Convention for the Prevention of Pollution From Ships', 'Convention on Biological Diversity', 'London Convention', 'Inter American Convention for the Protection and Conservation of Sea Turtles', 'Protocols to Regional Seas Conventions on Pollution from Land Based Sources'], 'A paration for the followup to the Strategic Plan for Biodiversity 20112020 and the Strategic Plan for the Cartagena Protocol on Biosafety 20112020.pdf.txt': ['Convention on Biological Diversity', 'Cartagena Protocol on Biosafety', 'Nagoya – Kuala Lumpur Supplementary Protocol'], 'African cherry Prunus africana.txt': ['None'], 'COP411 Cooperation with the European Union.txt': ['None'], 'Environmental assessmentinformation system, monitoring and early warning xe2x80x93 Article 12 of the Carpathian Convention.txt': ['None'], 'Hexachlorobutadiene.txt': ['Stockholm Convention'], 'Outcome of the UNCCD 1st Scientific Conference.pdf.txt': ['None'], 'Preparation for the followup to the Strategic Plan for Biodiversity 20112020.pdf.txt': ['Convention on Biological Diversity', 'NAGOYA PROTOCOL ON ACCESS TO GENETIC RESOURCES', 'NAGOYA PROTOCOL ON ACCESS AND BENEFIT-SHARING'], 'Process for aligning national reporting, assessment and review.pdf.txt': ['Convention on Biological Diversity', 'Rio conventions', 'Cartagena Protocol', 'Nagoya Protocol'], 'Pyu Ancient Cities Myanmar C 1444.txt': ['None'], 'Review of annexes A and B.pdf.txt': ['Minamata Convention on Mercury'], 'Submission regarding Swaziland.txt': ['Basel Convention']}
# tfidf matrix successfully created.
# time TF-IDF:  3.7522690296173096
# ([0.16724433679928244, 0.16724433679928244, 0.15087784557597175, 0.14817598327992137, 0.13933328478855622, 0.13933328478855622, 0.13933328478855622, 0.13933328478855622, 0.13933328478855622, 0.13933328478855622], ['Protocol implementation Alpine Convention field mountain agriculture', 'Protocol implementation Alpine Convention field mountain forests', 'Protocol Cypriot Republic European Union participation Cyprus European Environment Agency European Environment Information Observation Network N 5III2001', 'Revised Convention Establishment European Organisation Nuclear Research', 'Protocol implementation Alpine Convention 1991 field tourism', 'Convention European Space Agency', 'Protocol Implementation 1991 Alpine Convention Soil Protection', 'Protocol implementation Alpine Convention 1991 field energy', 'Convention Establishment European Mediterranean Plant Protection Organisation', 'Protocol implementation Alpine Convention field town country planning sustainable development'])
# time FuzzySearch:  54.58039164543152
# ([0.5, 0.48275862068965514, 0.46153846153846156, 0.46153846153846156, 0.4482758620689655, 0.4375, 0.4358974358974359, 0.43243243243243246, 0.42105263157894735, 0.4193548387096774], ['Convention European Space Agency', 'Fourth ACPEEC Convention', 'Convention Protection Marine Environment Baltic Area', 'Convention Protection Marine Environment Baltic Area', 'Third ACPCEE Convention', 'International Convention Salvage', 'European Landscape Convention', 'International Convention Arrest Ships', 'Maroua Declaration', 'Application Safeguards Implementation Article III 1 4 Treaty NonProliferation Nuclear Weapons'])
# time SequenceMatcher:  22.821977376937866
# ([0.9047619047619048, 0.8888888888888888, 0.8823529411764706, 0.8813559322033898, 0.8805970149253731, 0.88, 0.8695652173913043, 0.8695652173913043, 0.8571428571428571, 0.8571428571428571], ['Nordic Environmental Protection Convention', 'Convention Protection Rhine', 'Agreement cooperation field environmental protection Hungary Belgium', 'Agreement cooperation sphere ecology environment protection', 'Agreement cooperation field environmental protection Hungary Norway', 'Convention Nuclear Safety', 'Convention Road Traffic', 'Convention Protection Environment Criminal Law', 'Revised Convention Navigation Rhine', 'Convention concerning Fishing Black'])
# time SequenceMatcher:  0.6467628479003906
# ([0.00857142857142857, 0.00857142857142857, 0.00857142857142857, 0.00857142857142857, 0.00857142857142857, 0.00857142857142857, 0.00857142857142857, 0.00857142857142857, 0.00857142857142857, 0.00857142857142857], ['Revised Convention Navigation Rhine', 'Protocol implementation Alpine Convention 1991 field energy', 'Agreement Government Russian Federation Portugal cooperation sphere civil protection, prevention mitigation emergency situations', 'Agreement Government Russian Federation Government Kazakhstan scientific technical cooperation realization experimental thermonuclear reactor', 'Northwest Wildland Fire Protection Agreement', 'Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Agreement form Exchange Letters concerning provisional application Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Protocol implementation Alpine Convention 1991 field tourism', 'Protocol Implementation 1991 Alpine Convention Soil Protection', 'Kyoto Protocol United Nations Framework Convention Climate Change'])
# {'Management of Marine Debris.txt': ['International Convention for the Prevention of Pollution From Ships', 'Convention on Biological Diversity', 'London Convention', 'Inter American Convention for the Protection and Conservation of Sea Turtles', 'Protocols to Regional Seas Conventions on Pollution from Land Based Sources'], 'A paration for the followup to the Strategic Plan for Biodiversity 20112020 and the Strategic Plan for the Cartagena Protocol on Biosafety 20112020.pdf.txt': ['Convention on Biological Diversity', 'Cartagena Protocol on Biosafety', 'Nagoya – Kuala Lumpur Supplementary Protocol'], 'African cherry Prunus africana.txt': ['None'], 'COP411 Cooperation with the European Union.txt': ['None'], 'Environmental assessmentinformation system, monitoring and early warning xe2x80x93 Article 12 of the Carpathian Convention.txt': ['None'], 'Hexachlorobutadiene.txt': ['Stockholm Convention'], 'Outcome of the UNCCD 1st Scientific Conference.pdf.txt': ['None'], 'Preparation for the followup to the Strategic Plan for Biodiversity 20112020.pdf.txt': ['Convention on Biological Diversity', 'NAGOYA PROTOCOL ON ACCESS TO GENETIC RESOURCES', 'NAGOYA PROTOCOL ON ACCESS AND BENEFIT-SHARING'], 'Process for aligning national reporting, assessment and review.pdf.txt': ['Convention on Biological Diversity', 'Rio conventions', 'Cartagena Protocol', 'Nagoya Protocol'], 'Pyu Ancient Cities Myanmar C 1444.txt': ['None'], 'Review of annexes A and B.pdf.txt': ['Minamata Convention on Mercury'], 'Submission regarding Swaziland.txt': ['Basel Convention']}
# tfidf matrix successfully created.
# time TF-IDF:  4.58420205116272
# ([0.28220482107906353, 0.23919740741455678, 0.1883090996189089, 0.1883090996189089, 0.18066782805678752, 0.1455172222155946, 0.1455172222155946, 0.1455172222155946, 0.1455172222155946, 0.1455172222155946], ['Stockholm Convention Persistent Organic Pollutants', 'Protocol 1979 Convention LongRange Transboundary Air Pollution Persistent Organic Pollutants', 'Protocol amend Paragraph 2 Article X International Convention Conservation Atlantic Tunas', 'Amendment Paragraph 1, Article XIII Convention Conservation Living Resources Southeast Atlantic', 'Protocol 1979 Convention Longrange Transboundary Air Pollution LongTerm Financing Cooperative Programme Monitoring Evaluation Long Range Transmission Air Pollutants Europe EMEP', 'Bamako Convention Ban Import Africa Control Transboundary Movement Management Hazardous Wastes within Africa', 'Convention establishing Permanent InterState Drought Control Committee Sahel', 'Convention Prohibition Military Hostile Use Environmental Modification Techniques', 'Amendment Convention Environmental Impact Assessment Transboundary Context', 'Convention Conservation Management Fishery Resources South East Atlantic Ocean SEAFO'])
# time FuzzySearch:  41.49496078491211
# ([0.8431372549019608, 0.5217391304347826, 0.5217391304347826, 0.5185185185185186, 0.5, 0.5, 0.48275862068965514, 0.46153846153846156, 0.4545454545454546, 0.4482758620689655], ['Stockholm Convention Persistent Organic Pollutants', 'Third ACPCEE Convention', 'Convention High', 'London Fisheries Convention', 'Food Assistance Convention', 'Fourth ACPEEC Convention', 'United Nations Convention Law', 'Convention Protection Rhine', 'Convention Continental Shelf', 'Convention Regulation Whaling'])
# time SequenceMatcher:  24.9750497341156
# ([0.896551724137931, 0.8928571428571429, 0.8857142857142857, 0.8809523809523809, 0.8666666666666667, 0.8666666666666667, 0.8666666666666667, 0.864406779661017, 0.8604651162790697, 0.8596491228070176], ['Convention Regulation Whaling', 'Convention Continental Shelf', 'Agreement transboundary cooperation', 'Nordic Environmental Protection Convention', 'Protocol Energy', 'Paris Agreement', 'Convention High', 'Agreement cooperation sphere ecology environment protection', 'Benelux Convention Hunting Protection Birds', 'Convention Conservation Management Pollock Central Bering'])
# time SequenceMatcher:  0.5857017040252686
# ([0.00857142857142857, 0.00857142857142857, 0.00857142857142857, 0.00857142857142857, 0.00857142857142857, 0.00857142857142857, 0.00857142857142857, 0.00857142857142857, 0.00857142857142857, 0.00857142857142857], ['Revised Convention Navigation Rhine', 'Protocol implementation Alpine Convention 1991 field energy', 'Agreement Government Russian Federation Portugal cooperation sphere civil protection, prevention mitigation emergency situations', 'Agreement Government Russian Federation Government Kazakhstan scientific technical cooperation realization experimental thermonuclear reactor', 'Northwest Wildland Fire Protection Agreement', 'Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Agreement form Exchange Letters concerning provisional application Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Protocol implementation Alpine Convention 1991 field tourism', 'Protocol Implementation 1991 Alpine Convention Soil Protection', 'Kyoto Protocol United Nations Framework Convention Climate Change'])
# {'Management of Marine Debris.txt': ['International Convention for the Prevention of Pollution From Ships', 'Convention on Biological Diversity', 'London Convention', 'Inter American Convention for the Protection and Conservation of Sea Turtles', 'Protocols to Regional Seas Conventions on Pollution from Land Based Sources'], 'A paration for the followup to the Strategic Plan for Biodiversity 20112020 and the Strategic Plan for the Cartagena Protocol on Biosafety 20112020.pdf.txt': ['Convention on Biological Diversity', 'Cartagena Protocol on Biosafety', 'Nagoya – Kuala Lumpur Supplementary Protocol'], 'African cherry Prunus africana.txt': ['None'], 'COP411 Cooperation with the European Union.txt': ['None'], 'Environmental assessmentinformation system, monitoring and early warning xe2x80x93 Article 12 of the Carpathian Convention.txt': ['None'], 'Hexachlorobutadiene.txt': ['Stockholm Convention'], 'Outcome of the UNCCD 1st Scientific Conference.pdf.txt': ['None'], 'Preparation for the followup to the Strategic Plan for Biodiversity 20112020.pdf.txt': ['Convention on Biological Diversity', 'NAGOYA PROTOCOL ON ACCESS TO GENETIC RESOURCES', 'NAGOYA PROTOCOL ON ACCESS AND BENEFIT-SHARING'], 'Process for aligning national reporting, assessment and review.pdf.txt': ['Convention on Biological Diversity', 'Rio conventions', 'Cartagena Protocol', 'Nagoya Protocol'], 'Pyu Ancient Cities Myanmar C 1444.txt': ['None'], 'Review of annexes A and B.pdf.txt': ['Minamata Convention on Mercury'], 'Submission regarding Swaziland.txt': ['Basel Convention']}
# tfidf matrix successfully created.
# time TF-IDF:  5.78061842918396
# ([0.11514866314821248, 0.11331381642873574, 0.11022308643950021, 0.10946506266256083, 0.10799864593334116, 0.10639075460140096, 0.10423164633614207, 0.10221441759340358, 0.10185825432007767, 0.10122053841894557], ['Protocol Protection Marine Environment Black Land Based Sources Activities', 'Protocol concerning Pollution LandBased sources activities Convention Protection Development Marine Environment Wider Caribbean Region', 'International Convention Prevention Pollution Ships MARPOL Annex V Optional Garbage', 'Protocol Protection Caspian Pollution LandBased Sources Activities Framework Convention Protection Marine Environment Caspian', 'Kuwait Regional Convention Cooperation Protection Marine Environment Pollution', 'Protocol concerning Regional Preparedness, Response CoOperation combating Oil Pollution Incidents Framework Convention Protection Marine Environment Caspian', 'International Convention Prevention Pollution Ships MARPOL modified Protocol 1978 MARPOL 7378', 'Protocol Protection Marine Environment Pollution LandBased Sources', 'Amended Nairobi Convention Protection, Management Development Marine Coastal Environment Western Indian Ocean', 'Protocol Concerning Specially Protected Areas Wildlife Convention Protection Development Marine Environment Wider Caribbean Region'])
# time FuzzySearch:  652.8163030147552
# ([0.8235294117647058, 0.7058823529411764, 0.6956521739130435, 0.65625, 0.6206896551724138, 0.6097560975609756, 0.6097560975609756, 0.6097560975609756, 0.5882352941176471, 0.5853658536585367], ['Convention Biological Diversity', 'International Convention Prevention Pollution Ships', 'Convention International Maritime Organization', 'International Convention Salvage', 'Convention Protection Rhine', 'International Convention Protection Birds', 'International Convention Arrest Ships', 'International Convention Safe Containers', 'Protocol Forestry', 'International Convention Safety Life'])
# time SequenceMatcher:  350.92009592056274
# ([0.9759036144578314, 0.9714285714285714, 0.967741935483871, 0.9666666666666667, 0.9607843137254902, 0.9571428571428572, 0.9545454545454546, 0.9504950495049505, 0.9482758620689655, 0.9473684210526315], ['Agreement protection appellations origin safeguarding designations certain products', 'Agreement transboundary cooperation', 'Agreement fisheries enforcement', 'Acuerdo materia sanidad animal', 'Agreement establishment global crop diversity trust', 'Protocol conditions relating reciprocal access fishing vessels Parties', 'Tratado medio ambiente', 'Agreement government Hellenic Republic government Republic Moldova economic technological cooperation', 'Regional Agreement transboundary movement hazardous wastes', 'Convention civil liability damage resulting activities dangerous environment'])
# time SequenceMatcher:  11.84371566772461
# ([0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285], ['Revised Convention Navigation Rhine', 'Protocol implementation Alpine Convention 1991 field energy', 'Agreement Government Russian Federation Portugal cooperation sphere civil protection, prevention mitigation emergency situations', 'Agreement Government Russian Federation Government Kazakhstan scientific technical cooperation realization experimental thermonuclear reactor', 'Northwest Wildland Fire Protection Agreement', 'Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Agreement form Exchange Letters concerning provisional application Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Protocol implementation Alpine Convention 1991 field tourism', 'Protocol Implementation 1991 Alpine Convention Soil Protection', 'Kyoto Protocol United Nations Framework Convention Climate Change'])
# {'Management of Marine Debris.txt': ['International Convention for the Prevention of Pollution From Ships', 'Convention on Biological Diversity', 'London Convention', 'Inter American Convention for the Protection and Conservation of Sea Turtles', 'Protocols to Regional Seas Conventions on Pollution from Land Based Sources'], 'A paration for the followup to the Strategic Plan for Biodiversity 20112020 and the Strategic Plan for the Cartagena Protocol on Biosafety 20112020.pdf.txt': ['Convention on Biological Diversity', 'Cartagena Protocol on Biosafety', 'Nagoya – Kuala Lumpur Supplementary Protocol'], 'African cherry Prunus africana.txt': ['None'], 'COP411 Cooperation with the European Union.txt': ['None'], 'Environmental assessmentinformation system, monitoring and early warning xe2x80x93 Article 12 of the Carpathian Convention.txt': ['None'], 'Hexachlorobutadiene.txt': ['Stockholm Convention'], 'Outcome of the UNCCD 1st Scientific Conference.pdf.txt': ['None'], 'Preparation for the followup to the Strategic Plan for Biodiversity 20112020.pdf.txt': ['Convention on Biological Diversity', 'NAGOYA PROTOCOL ON ACCESS TO GENETIC RESOURCES', 'NAGOYA PROTOCOL ON ACCESS AND BENEFIT-SHARING'], 'Process for aligning national reporting, assessment and review.pdf.txt': ['Convention on Biological Diversity', 'Rio conventions', 'Cartagena Protocol', 'Nagoya Protocol'], 'Pyu Ancient Cities Myanmar C 1444.txt': ['None'], 'Review of annexes A and B.pdf.txt': ['Minamata Convention on Mercury'], 'Submission regarding Swaziland.txt': ['Basel Convention']}
# tfidf matrix successfully created.
# time TF-IDF:  4.700796365737915
# ([0.15060890856781062, 0.15060890856781062, 0.1492042575888882, 0.14175107214813013, 0.1384579667653777, 0.13795181155955774, 0.13795181155955774, 0.13168940577404215, 0.13168940577404215, 0.13168940577404215], ['Agreement Ministry Agriculture Water Management Uzbekistan Ministry Agriculture Processing Industry Moldova economic, scientific technical cooperation', 'Agreement Ministry Agriculture Water Management Uzbekistan Ministry Agriculture Food Russian Federation economic, scientific technical cooperation', 'Agreement Ministry Agriculture Russian Federation Ministry Land Management Slovakia economic, scientific technical cooperation sphere agriculture', 'Protocol forth session Joint GreekAlbanian interministerial Committee economic, industrial, technical scientific cooperation Governments Republic Greece Republic Albania', 'Agreement form Exchange Letters concerning provisional application amendments Protocol establishing fishing opportunities compensation provided Agreement European Economic Community Government Republic GuineaBissau fishing coast GuineaBissau period 16 June 2001 15 June 2006, Decision 2001179EEC setting terms financial support GuineaBissau fisheries sector', 'Protocol first session joint GreekRomanian Commission scientific technological cooperation', 'Protocol session Joint GreekYugoslav Commission scientific technological cooperation', 'Protocol first session Joint GreekEgyptian Committee scientific technological cooperation', 'Protocol fifth session Joint GreekItalian Committee scientific technological cooperation', 'Protocol first session GreekArmenian Joint Committee scientific technological cooperation'])
# time FuzzySearch:  70.31425261497498
# ([0.44999999999999996, 0.4390243902439024, 0.4285714285714286, 0.4285714285714286, 0.4193548387096774, 0.4117647058823529, 0.4117647058823529, 0.40740740740740744, 0.4, 0.4], ['Maroua Declaration', 'Framework Convention Tobacco Control FCTC', 'Convention Continental Shelf', 'Constitution International Rice Commission', 'Convention Regulation Whaling', 'Constitution Center International Forestry Research', 'Convention Protection Rhine', 'London Fisheries Convention', 'Agreement Conservation Seals Wadden', 'Agreement Conservation Polar Bears'])
# time SequenceMatcher:  36.651206731796265
# ([0.8979591836734694, 0.8857142857142857, 0.8823529411764706, 0.875, 0.8723404255319149, 0.8604651162790697, 0.8571428571428571, 0.8571428571428571, 0.8571428571428571, 0.8536585365853658], ['Convention concerning supply water Commune Menton', 'Convention concerning Fishing Black', 'International agreement river Maas', 'Antarctic Treaty', 'Agreement concerning cooperation Marine Fishing', 'Convention concerning Fishing Waters Danube', 'Energy Charter Treaty', 'Agreement plant protection cooperation Croatia Macedonia', 'Constitution International Rice Commission', 'Cooperation agreement Uzbekistan Slovakia'])
# time SequenceMatcher:  1.2400460243225098
# ([0.006571428571428572, 0.006571428571428572, 0.006571428571428572, 0.006571428571428572, 0.006571428571428572, 0.006571428571428572, 0.006571428571428572, 0.006571428571428572, 0.006571428571428572, 0.006571428571428572], ['Revised Convention Navigation Rhine', 'Protocol implementation Alpine Convention 1991 field energy', 'Agreement Government Russian Federation Portugal cooperation sphere civil protection, prevention mitigation emergency situations', 'Agreement Government Russian Federation Government Kazakhstan scientific technical cooperation realization experimental thermonuclear reactor', 'Northwest Wildland Fire Protection Agreement', 'Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Agreement form Exchange Letters concerning provisional application Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Protocol implementation Alpine Convention 1991 field tourism', 'Protocol Implementation 1991 Alpine Convention Soil Protection', 'Kyoto Protocol United Nations Framework Convention Climate Change'])
# {'Management of Marine Debris.txt': ['International Convention for the Prevention of Pollution From Ships', 'Convention on Biological Diversity', 'London Convention', 'Inter American Convention for the Protection and Conservation of Sea Turtles', 'Protocols to Regional Seas Conventions on Pollution from Land Based Sources'], 'A paration for the followup to the Strategic Plan for Biodiversity 20112020 and the Strategic Plan for the Cartagena Protocol on Biosafety 20112020.pdf.txt': ['Convention on Biological Diversity', 'Cartagena Protocol on Biosafety', 'Nagoya – Kuala Lumpur Supplementary Protocol'], 'African cherry Prunus africana.txt': ['None'], 'COP411 Cooperation with the European Union.txt': ['None'], 'Environmental assessmentinformation system, monitoring and early warning xe2x80x93 Article 12 of the Carpathian Convention.txt': ['None'], 'Hexachlorobutadiene.txt': ['Stockholm Convention'], 'Outcome of the UNCCD 1st Scientific Conference.pdf.txt': ['None'], 'Preparation for the followup to the Strategic Plan for Biodiversity 20112020.pdf.txt': ['Convention on Biological Diversity', 'NAGOYA PROTOCOL ON ACCESS TO GENETIC RESOURCES', 'NAGOYA PROTOCOL ON ACCESS AND BENEFIT-SHARING'], 'Process for aligning national reporting, assessment and review.pdf.txt': ['Convention on Biological Diversity', 'Rio conventions', 'Cartagena Protocol', 'Nagoya Protocol'], 'Pyu Ancient Cities Myanmar C 1444.txt': ['None'], 'Review of annexes A and B.pdf.txt': ['Minamata Convention on Mercury'], 'Submission regarding Swaziland.txt': ['Basel Convention']}
# tfidf matrix successfully created.
# time TF-IDF:  4.078486442565918
# ([0.3079755057864405, 0.17914519119735994, 0.16894852910658803, 0.16894852910658803, 0.16894852910658803, 0.15592908845832493, 0.15241400874759217, 0.1511573176991749, 0.1511573176991749, 0.14863304346881898], ['Nagoya Protocol Access Genetic Resources Fair Equitable Sharing Benefits Arising Utilization Convention Biological Diversity', 'Protocol conditions relating reciprocal access fishing vessels Parties', 'Protocol sixth Meeting scientific technological cooperation Joint Committee Hellenic Republic Republic Hungary', 'Protocol eighth Meeting scientific technological cooperation Joint Committee Hellenic Republic Republic Hungary', 'Protocol fifth Meeting Joint Greek Albanian Committee scientific technological cooperation', 'Nagoya Kuala Lumpur Supplementary Protocol Liability Redress Cartagena Protocol Biosafety', 'Black Biodiversity Landscape Conservation Protocol Convention Protection Black Pollution', 'Protocol claims, legal proceedings indemnification framework agreement multilateral nuclear environmental programme Russian Federation', 'Additional Protocol Framework agreement environment MERCOSUR', 'Protocol Conservation Sustainable Use Biological Landscape Diversity Framework Convention Protection Sustainable Development Carpathians'])
# time FuzzySearch:  61.844043254852295
# ([0.736842105263158, 0.6, 0.5882352941176471, 0.5555555555555556, 0.5384615384615384, 0.5294117647058824, 0.52, 0.5, 0.45833333333333337, 0.4516129032258065], ['Convention Biological Diversity', 'Cartagena Protocol Biosafety Convention Biological Diversity', 'Protocol Forestry', 'Protocol Fisheries', 'Food Assistance Convention', 'Protocol Energy', 'Third ACPCEE Convention', 'Protocol Mining', 'Protocol Dangerous Goods', 'Nagoya Protocol Access Genetic Resources Fair Equitable Sharing Benefits Arising Utilization Convention Biological Diversity'])
# time SequenceMatcher:  36.41918349266052
# ([0.9117647058823529, 0.9032258064516129, 0.8888888888888888, 0.8823529411764706, 0.8666666666666667, 0.8666666666666667, 0.8571428571428571, 0.8571428571428571, 0.8548387096774194, 0.8539325842696629], ['International agreement river Maas', 'Convention Biological Diversity', 'Protocol Fisheries', 'Protocol Forestry', 'Protocol Energy', 'Convention High', 'Convention Continental Shelf', 'Protocol Shared Watercourse Systems', 'Nagoya Protocol Access Genetic Resources Fair Equitable Sharing Benefits Arising Utilization Convention Biological Diversity', 'Convention Conservation Biodiversity Protection Priority Wilderness Areas Central America'])
# time SequenceMatcher:  1.1266064643859863
# ([0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285], ['Revised Convention Navigation Rhine', 'Protocol implementation Alpine Convention 1991 field energy', 'Agreement Government Russian Federation Portugal cooperation sphere civil protection, prevention mitigation emergency situations', 'Agreement Government Russian Federation Government Kazakhstan scientific technical cooperation realization experimental thermonuclear reactor', 'Northwest Wildland Fire Protection Agreement', 'Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Agreement form Exchange Letters concerning provisional application Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Protocol implementation Alpine Convention 1991 field tourism', 'Protocol Implementation 1991 Alpine Convention Soil Protection', 'Kyoto Protocol United Nations Framework Convention Climate Change'])
# {'Management of Marine Debris.txt': ['International Convention for the Prevention of Pollution From Ships', 'Convention on Biological Diversity', 'London Convention', 'Inter American Convention for the Protection and Conservation of Sea Turtles', 'Protocols to Regional Seas Conventions on Pollution from Land Based Sources'], 'A paration for the followup to the Strategic Plan for Biodiversity 20112020 and the Strategic Plan for the Cartagena Protocol on Biosafety 20112020.pdf.txt': ['Convention on Biological Diversity', 'Cartagena Protocol on Biosafety', 'Nagoya – Kuala Lumpur Supplementary Protocol'], 'African cherry Prunus africana.txt': ['None'], 'COP411 Cooperation with the European Union.txt': ['None'], 'Environmental assessmentinformation system, monitoring and early warning xe2x80x93 Article 12 of the Carpathian Convention.txt': ['None'], 'Hexachlorobutadiene.txt': ['Stockholm Convention'], 'Outcome of the UNCCD 1st Scientific Conference.pdf.txt': ['None'], 'Preparation for the followup to the Strategic Plan for Biodiversity 20112020.pdf.txt': ['Convention on Biological Diversity', 'NAGOYA PROTOCOL ON ACCESS TO GENETIC RESOURCES', 'NAGOYA PROTOCOL ON ACCESS AND BENEFIT-SHARING'], 'Process for aligning national reporting, assessment and review.pdf.txt': ['Convention on Biological Diversity', 'Rio conventions', 'Cartagena Protocol', 'Nagoya Protocol'], 'Pyu Ancient Cities Myanmar C 1444.txt': ['None'], 'Review of annexes A and B.pdf.txt': ['Minamata Convention on Mercury'], 'Submission regarding Swaziland.txt': ['Basel Convention']}
# tfidf matrix successfully created.
# time TF-IDF:  5.352057456970215
# ...
# tfidf matrix successfully created.
# time TF-IDF:  4.3390467166900635
# ([0.17907351913148015, 0.17907351913148015, 0.17423599072186494, 0.16730386215873752, 0.15921307042651844, 0.15921307042651844, 0.15921307042651844, 0.15921307042651844, 0.15921307042651844, 0.15921307042651844], ['Agreement State Forest Committee Ukraine Swiss Development Cooperation Board cooperation sphere forest management', 'First Session Joint Ministerial Committee Hellenic Republic State Israel', 'Agreement State Subsoil Board Armenia State Geology Subsoil Management Committee cooperation sphere geological exploration management subsoil', 'Agreement State Committee Water management Ukraine Ministry Irrigation Syria cooperation sphere water management', 'Agreement State Committee Standardization Metrology Russian Federation Ministry Development, Science Environment Yugoslavia testing imported commodities', 'Agreement State Committee Standardization, Metrology Certification Belarus Argentine Institute Materials Normalization IRAM cooperation sphere standardization compliance evaluation', 'Agreement State Agroindustrial Committee Russian Federation Ministry Agriculture Canada plant quarantine', 'Agreement Committee Standardization, Metrology Certification Belarus State Inspection Standardization Metrology Kyrgyzstan cooperation sphere standardization, metrology certification', 'Treaty Establishing Joint YemeniEritrean Committee Bilateral Cooperation Government Republic Yemen Government State Eritrea', 'Agreement State Committee Nuclear Radiation Safety Ukraine Federal Nuclear Safety Inspectorate Switzerland'])
# time FuzzySearch:  38.25452923774719
# ([0.5, 0.47058823529411764, 0.4444444444444444, 0.4444444444444444, 0.4285714285714286, 0.42307692307692313, 0.42105263157894735, 0.41666666666666663, 0.41025641025641024, 0.40909090909090906], ['Protocol Wildlife Conservation Law Enforcement', 'Agreement Conservation Polar Bears', 'Agreement Conservation European Bats', 'Convention Conservation Southern Bluefin Tuna', 'Agreement Conservation Albatrosses Petrels', 'Arms Trade Treaty', 'Convention High', 'Fourth ACPEEC Convention', 'Convention Conservation Antarctic Seals', 'Convention Conservation Nature South Pacific'])
# time SequenceMatcher:  20.850104808807373
# ([0.8888888888888888, 0.8857142857142857, 0.8823529411764706, 0.875, 0.8571428571428571, 0.8571428571428571, 0.8571428571428571, 0.8536585365853658, 0.8461538461538461, 0.8409090909090909], ['Agreement Conservation European Bats', 'Agreement Conservation Seals Wadden', 'Agreement Conservation Polar Bears', 'Agreement Conservation Gorillas Habitats', 'Convention concerning Fishing Black', 'Agreement transboundary cooperation', 'Agreement Conservation Albatrosses Petrels', 'Convention Conservation Management Vicuna', 'Convention Conservation Antarctic Seals', 'Amendment Agreement conservation bats Europe'])
# time SequenceMatcher:  0.6142129898071289
# ([0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285, 0.0074285714285714285], ['Revised Convention Navigation Rhine', 'Protocol implementation Alpine Convention 1991 field energy', 'Agreement Government Russian Federation Portugal cooperation sphere civil protection, prevention mitigation emergency situations', 'Agreement Government Russian Federation Government Kazakhstan scientific technical cooperation realization experimental thermonuclear reactor', 'Northwest Wildland Fire Protection Agreement', 'Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Agreement form Exchange Letters concerning provisional application Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Protocol implementation Alpine Convention 1991 field tourism', 'Protocol Implementation 1991 Alpine Convention Soil Protection', 'Kyoto Protocol United Nations Framework Convention Climate Change'])
# {'Management of Marine Debris.txt': ['International Convention for the Prevention of Pollution From Ships', 'Convention on Biological Diversity', 'London Convention', 'Inter American Convention for the Protection and Conservation of Sea Turtles', 'Protocols to Regional Seas Conventions on Pollution from Land Based Sources'], 'A paration for the followup to the Strategic Plan for Biodiversity 20112020 and the Strategic Plan for the Cartagena Protocol on Biosafety 20112020.pdf.txt': ['Convention on Biological Diversity', 'Cartagena Protocol on Biosafety', 'Nagoya – Kuala Lumpur Supplementary Protocol'], 'African cherry Prunus africana.txt': ['None'], 'COP411 Cooperation with the European Union.txt': ['None'], 'Environmental assessmentinformation system, monitoring and early warning xe2x80x93 Article 12 of the Carpathian Convention.txt': ['None'], 'Hexachlorobutadiene.txt': ['Stockholm Convention'], 'Outcome of the UNCCD 1st Scientific Conference.pdf.txt': ['None'], 'Preparation for the followup to the Strategic Plan for Biodiversity 20112020.pdf.txt': ['Convention on Biological Diversity', 'NAGOYA PROTOCOL ON ACCESS TO GENETIC RESOURCES', 'NAGOYA PROTOCOL ON ACCESS AND BENEFIT-SHARING'], 'Process for aligning national reporting, assessment and review.pdf.txt': ['Convention on Biological Diversity', 'Rio conventions', 'Cartagena Protocol', 'Nagoya Protocol'], 'Pyu Ancient Cities Myanmar C 1444.txt': ['None'], 'Review of annexes A and B.pdf.txt': ['Minamata Convention on Mercury'], 'Submission regarding Swaziland.txt': ['Basel Convention']}
# tfidf matrix successfully created.
# time TF-IDF:  4.101182222366333
# ([0.14414202898684836, 0.11496027514276022, 0.11186084107516663, 0.10949514104368806, 0.10901066855520611, 0.10570896547025505, 0.10435292783853414, 0.10435292783853414, 0.10435292783853414, 0.09924173180083234], ['Minamata Convention Mercury', 'Protocol amend Paragraph 2 Article X International Convention Conservation Atlantic Tunas', 'Amendment Paragraph 1, Article XIII Convention Conservation Living Resources Southeast Atlantic', 'Agreement European Community United States America sanitary measures protect public animal health trade live animals animal products', 'Agreement form exchange letters concerning amendments annexes Agreement European Community United States America sanitary measures protect public animal health trade live animals animal products', 'Amendment Annex B Kyoto Protocol United Nations Framework Convention Climate Change', 'Protocol Pollutant Release Transfer Registers Convention Access Information, PublicParticipation DecisionMaking Access Justice Environmental Matters', 'Convention Access Information, Public Participation DecisionMaking Access Justice Environmental Matters', 'Amendment Convention Access Information, Public Participation DecisionMaking Access Justice Environmental Matters', 'Decision 22003 Joint Veterinary Committee set Agreement European Community Swiss Confederation trade agricultural products amending Appendices 1, 2, 3, 4, 5, 6 11 Annex 11 Agreement'])
# time FuzzySearch:  216.36121726036072
# ([0.8, 0.5609756097560976, 0.56, 0.5416666666666667, 0.5263157894736843, 0.5227272727272727, 0.5227272727272727, 0.5217391304347826, 0.5151515151515151, 0.5128205128205128], ['Minamata Convention Mercury', 'Convention Conservation Anadromous Stocks', 'Convention Nuclear Safety', 'Fourth ACPEEC Convention', 'Convention High', 'Convention Conservation Nature South Pacific', 'Convention International Council Exploration', 'Third ACPCEE Convention', 'Convention Protection Rhine', 'Convention Conservation Antarctic Seals'])
# time SequenceMatcher:  118.0013918876648
# ([0.9545454545454546, 0.9411764705882353, 0.9333333333333333, 0.9298245614035088, 0.9193548387096774, 0.9166666666666666, 0.9130434782608695, 0.9117647058823529, 0.9090909090909091, 0.9], ['Tratado medio ambiente', 'Accord concernant lexportation vins italiens Suisse', 'Acuerdo materia sanidad animal', 'CIS Agreement cooperation sphere timber industry forestry', 'Agreement Russian Federation Finland boundary water ecosystems', 'Convention concerning protection ItaloSwiss waters pollution', 'Convention International Maritime Organization', 'International agreement river Maas', 'Amendment Agreement conservation bats Europe', 'Statuts lAgence africaine biotechnologie'])
# time SequenceMatcher:  3.9184017181396484
# ([0.008285714285714287, 0.008285714285714287, 0.008285714285714287, 0.008285714285714287, 0.008285714285714287, 0.008285714285714287, 0.008285714285714287, 0.008285714285714287, 0.008285714285714287, 0.008285714285714287], ['Revised Convention Navigation Rhine', 'Protocol implementation Alpine Convention 1991 field energy', 'Agreement Government Russian Federation Portugal cooperation sphere civil protection, prevention mitigation emergency situations', 'Agreement Government Russian Federation Government Kazakhstan scientific technical cooperation realization experimental thermonuclear reactor', 'Northwest Wildland Fire Protection Agreement', 'Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Agreement form Exchange Letters concerning provisional application Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Protocol implementation Alpine Convention 1991 field tourism', 'Protocol Implementation 1991 Alpine Convention Soil Protection', 'Kyoto Protocol United Nations Framework Convention Climate Change'])
# {'Management of Marine Debris.txt': ['International Convention for the Prevention of Pollution From Ships', 'Convention on Biological Diversity', 'London Convention', 'Inter American Convention for the Protection and Conservation of Sea Turtles', 'Protocols to Regional Seas Conventions on Pollution from Land Based Sources'], 'A paration for the followup to the Strategic Plan for Biodiversity 20112020 and the Strategic Plan for the Cartagena Protocol on Biosafety 20112020.pdf.txt': ['Convention on Biological Diversity', 'Cartagena Protocol on Biosafety', 'Nagoya – Kuala Lumpur Supplementary Protocol'], 'African cherry Prunus africana.txt': ['None'], 'COP411 Cooperation with the European Union.txt': ['None'], 'Environmental assessmentinformation system, monitoring and early warning xe2x80x93 Article 12 of the Carpathian Convention.txt': ['None'], 'Hexachlorobutadiene.txt': ['Stockholm Convention'], 'Outcome of the UNCCD 1st Scientific Conference.pdf.txt': ['None'], 'Preparation for the followup to the Strategic Plan for Biodiversity 20112020.pdf.txt': ['Convention on Biological Diversity', 'NAGOYA PROTOCOL ON ACCESS TO GENETIC RESOURCES', 'NAGOYA PROTOCOL ON ACCESS AND BENEFIT-SHARING'], 'Process for aligning national reporting, assessment and review.pdf.txt': ['Convention on Biological Diversity', 'Rio conventions', 'Cartagena Protocol', 'Nagoya Protocol'], 'Pyu Ancient Cities Myanmar C 1444.txt': ['None'], 'Review of annexes A and B.pdf.txt': ['Minamata Convention on Mercury'], 'Submission regarding Swaziland.txt': ['Basel Convention']}
# tfidf matrix successfully created.
# time TF-IDF:  4.021511554718018
# ([0.15473500077247207, 0.15473500077247207, 0.15193604309276743, 0.1426165273286113, 0.13272963079964517, 0.13243985602595187, 0.13196732693278546, 0.13083704942094662, 0.13083704942094662, 0.1282501079017398], ['Amendment Basel Convention Control Transboundary Movements Hazardous Wastes Disposal', 'Basel Convention Control Transboundary Movements Hazardous Wastes Disposal', 'Agreement Government Republic South Africa, Government Kingdom Swaziland Government Peoples Republic Mozambique relative establishment Tripartite Permanent Technical Committee', 'Convention establishing Permanent InterState Drought Control Committee Sahel', 'Agreement Committee Standardization, Metrology Certification Belarus National Bureau Certification Cuba cooperation sphere certification', 'Environmental Cooperation Action Plan Government Canada Government Peoples Republic China', 'Agreement Action Plan Environmentally Sound Management Common Zambezi River System', 'Agreement State Committee Fisheries Fishing Industry Ukraine Federal Fisheries Committee Russian Federation regarding fisheries 1993', 'International Agreement State Committee Construction, Architecture Housing Policy Ukraine State Committee Construction, Housing Communal Services regarding coordination land use planning boundary territories', 'Protocol 1979 Convention Longrange Transboundary Air Pollution LongTerm Financing Cooperative Programme Monitoring Evaluation Long Range Transmission Air Pollutants Europe EMEP'])
# time FuzzySearch:  66.10797548294067
# ([0.6875, 0.5, 0.5, 0.48275862068965514, 0.4814814814814815, 0.4814814814814815, 0.48, 0.48, 0.46875, 0.46875], ['Convention High', 'Fourth ACPEEC Convention', 'Convention Continental Shelf', 'Convention Regulation Whaling', 'Convention Protection Rhine', 'London Fisheries Convention', 'Convention Road Traffic', 'Convention Nuclear Safety', 'Treaty Amazonian Cooperation', 'Great Lakes Fisheries Convention'])
# time SequenceMatcher:  37.399943113327026
# ([0.9411764705882353, 0.9019607843137255, 0.8888888888888888, 0.88, 0.875, 0.8717948717948718, 0.8666666666666667, 0.8666666666666667, 0.8571428571428571, 0.8529411764705882], ['International agreement river Maas', 'Convention International Commission Protection Elbe', 'Convention Protection Rhine', 'Convention Nuclear Safety', 'Antarctic Treaty', 'Agreement establishing Pepper Community', 'Acuerdo materia sanidad animal', 'Convention High', 'Constitution International Rice Commission', 'Agreement cooperation field environmental protection Hungary Belgium'])
# time SequenceMatcher:  1.1768991947174072
# ([0.008, 0.008, 0.008, 0.008, 0.008, 0.008, 0.008, 0.008, 0.008, 0.008], ['Revised Convention Navigation Rhine', 'Protocol implementation Alpine Convention 1991 field energy', 'Agreement Government Russian Federation Portugal cooperation sphere civil protection, prevention mitigation emergency situations', 'Agreement Government Russian Federation Government Kazakhstan scientific technical cooperation realization experimental thermonuclear reactor', 'Northwest Wildland Fire Protection Agreement', 'Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Agreement form Exchange Letters concerning provisional application Protocol establishing, period 1 July 1997 30 June 2000, fishing rights financial compensation provided Agreement European Economic Community Government Republic Equatorial Guinea fishing coast Equatorial Guinea', 'Protocol implementation Alpine Convention 1991 field tourism', 'Protocol Implementation 1991 Alpine Convention Soil Protection', 'Kyoto Protocol United Nations Framework Convention Climate Change'])
# ENDE

# %% [markdown]
# # See accuracy of different methods
# ## Run Different Methods and compare them to the right answers

# %%
list_of_subfolders = ['Train Data']

def tf_idf():
    text_list = []
    name_list = []
    for subfolder in list_of_subfolders: #loop over subfolders
        list_of_files = listdir("Downloads/" + subfolder) #get all files

        for filename in list_of_files: #go through files in subfolder
            
            if (filename[-3:] == "txt"):  #check if it is a txt document
                with open("Downloads/" + subfolder + "/" + filename, encoding = "utf8") as f:
                    document_text = f.readlines()
                    
               
                #clean the document
                text = " ".join(document_text) #create long string 
                text = text.lower()
                text = re.sub("</?.*?>"," <> ", text) # remove tags
                text = re.sub("(\\d|\\W)+"," ", text).strip() # remove special characters and digits
                text = text.split()
                
                
                text_list.append(' '.join(text))
                name_list.append(filename)
                
        start_time = time.time()        
        '''
        VERSION 0: TF-IDF Matrix
        Super Quick, However, not very accurate so far
        '''


        X,v = create_tfidf_features(text_list)
        features = v.get_feature_names()



        
        similarities = calculate_similarity(X, v, treaty_names)
        search_time = time.time() - start_time
        similarities = np.array(similarities).T
        for num, sims in enumerate(similarities):
            list_sim = []
            for sim in sims:
                list_sim.append(float(sim))
            print("time TF-IDF: ", search_time)
            print('filename: ', name_list[num])
            print(find_top_X(list_sim, treaty_names, 10))
            print()
            print()
                

def fuzzy_search():
    

    for subfolder in list_of_subfolders: #loop over subfolders
        list_of_files = listdir("Downloads/" + subfolder) #get all files
        counter = 0
        for filename in list_of_files: #go through files in subfolder
            list_of_outcomes = []
            

            
            if (filename[-3:] == "txt"):  #check if it is a txt document
                with open("Downloads/" + subfolder + "/" + filename, encoding = "utf8") as f:
                    document_text = f.readlines()
                    
                
                #clean the document
                text = " ".join(document_text) #create long string 
                text = text.lower()
                text = re.sub("</?.*?>"," <> ", text) # remove tags
                text = re.sub("(\\d|\\W)+"," ", text).strip() # remove special characters and digits
                text = text.split()
                
                start_time = time.time()
            
                for treaty in treaty_names: 
                    '''
                    VERSION 1: Use fuzzy search
                    As fuzzysearch doesn't work well if the string length differ widely,
                    the code loops over different overlaping parts of the text and saves the highest score
                    '''
                    high_score = 0
                    name_len = len(treaty.split()) #see how long the treaty name is
                    for num  in range(0, len(text) - 2 - name_len, (name_len + 2) // 2): #get the length of the text and get a step size that is according to the name length

                        #use fuzzy search to see the match for the specific part of the text
                        Search_Query = fuzzyset.FuzzySet()
                        Search_Query.add(treaty)
                        outcome = Search_Query.get(" ".join(text[num:num + name_len + 2]))


                        if outcome != None: #check if the match is None (None will cause error)
                            if outcome[0][0] > high_score: #check if the current score is larger than the highest score
                                high_score = outcome[0][0] #update highscore
                    list_of_outcomes.append(high_score)

                #add outcomes to df, save df
                print('time FuzzySearch: ', time.time() - start_time)
                print('filename: ', filename)
                print(find_top_X(list_of_outcomes, treaty_names, 10))
                print()
                print()
                
                

def sequence_matcher():
    for subfolder in list_of_subfolders: #loop over subfolders
        list_of_files = listdir("Downloads/" + subfolder) #get all files

        for filename in list_of_files: #go through files in subfolder
            
            if (filename[-3:] == "txt"):  #check if it is a txt document
                with open("Downloads/" + subfolder + "/" + filename, encoding = "utf8") as f:
                    document_text = f.readlines()
                    
                
                #clean the document
                text = " ".join(document_text) #create long string 
                text = text.lower()
                text = re.sub("</?.*?>"," <> ", text) # remove tags
                text = re.sub("(\\d|\\W)+"," ", text).strip() # remove special characters and digits
                text = text.split()
                
                start_time = time.time()
                list_of_outcomes = []
                for treaty in treaty_names: 
                    '''
                    VERSION 2: SequenceMatcher
                    Different library - roughly three times faster
                    does not need to loop over 
                    '''
                    
                    
                    s = difflib.SequenceMatcher(None, ''.join(text), treaty)
                    high_score = sum(n for i,j,n in s.get_matching_blocks()) / float(len(treaty))
                    list_of_outcomes.append(high_score)
                    
                #add outcomes to df, save df
                print('time SequenceMatcher: ', time.time() - start_time)
                print('filename: ', filename)
                print(find_top_X(list_of_outcomes, treaty_names, 10))
                print()
                print()

# %%
print('CORRECT ANSWERS: \n')
for key in dict_of_correct_answers:
    print(key)
    print(dict_of_correct_answers[key])
    print()
    
tf_idf()
# Out:
# CORRECT ANSWERS:
#
# Management of Marine Debris.txt
# ['International Convention for the Prevention of Pollution From Ships', 'Convention on Biological Diversity', 'London Convention', 'Inter American Convention for the Protection and Conservation of Sea Turtles', 'Protocols to Regional Seas Conventions on Pollution from Land Based Sources']
#
# A paration for the followup to the Strategic Plan for Biodiversity 20112020 and the Strategic Plan for the Cartagena Protocol on Biosafety 20112020.pdf.txt
# ['Convention on Biological Diversity', 'Cartagena Protocol on Biosafety', 'Nagoya – Kuala Lumpur Supplementary Protocol']
#
# African cherry Prunus africana.txt
# ['None']
#
# COP411 Cooperation with the European Union.txt
# ['None']
#
# Environmental assessmentinformation system, monitoring and early warning xe2x80x93 Article 12 of the Carpathian Convention.txt
# ['None']
#
# Hexachlorobutadiene.txt
# ['Stockholm Convention']
#
# Outcome of the UNCCD 1st Scientific Conference.pdf.txt
# ['None']
#
# Preparation for the followup to the Strategic Plan for Biodiversity 20112020.pdf.txt
# ['Convention on Biological Diversity', 'NAGOYA PROTOCOL ON ACCESS TO GENETIC RESOURCES', 'NAGOYA PROTOCOL ON ACCESS AND BENEFIT-SHARING']
#
# Process for aligning national reporting, assessment and review.pdf.txt
# ['Convention on Biological Diversity', 'Rio conventions', 'Cartagena Protocol', 'Nagoya Protocol']
#
# Pyu Ancient Cities Myanmar C 1444.txt
# ['None']
#
# Review of annexes A and B.pdf.txt
# ['Minamata Convention on Mercury']
#
# Submission regarding Swaziland.txt
# ['Basel Convention']
#
# tfidf matrix successfully created.
# time TF-IDF:  3.4840216636657715
# filename:  A paration for the followup to the Strategic Plan for Biodiversity 20112020 and the Strategic Plan for the Cartagena Protocol on Biosafety 20112020.pdf.txt
# ([0.3927879477577464, 0.3927879477577464, 0.29840615175231855, 0.16713949274675974, 0.15734919900058564, 0.15432792493680747, 0.15432792493680747, 0.15432792493680747, 0.15432792493680747, 0.15432792493680747], ['Nagoya Kuala Lumpur Supplementary Protocol Liability Redress Cartagena Protocol Biosafety', 'Nagoya Kuala Lumpur Supplementary Protocol Liability Redress Cartagena Protocol Biosafety', 'Cartagena Protocol Biosafety Convention Biological Diversity', 'Protocol amend Convention 31 January 1963 Supplementary Paris Convention 29 July 1960 Third Party Liability Field Nuclear Energy, amended Additional Protocol', 'Protocol amend Convention Third Party Liability Field Nuclear Energy 29 July 1960, amended Additional Protocol 28 January 1964 Protocol 16 November 19', 'Protocol Mining', 'Protocol Comprehensive Nuclear TestBan Treaty', 'Protocol Energy', 'Protocol Treaty German Democratic Republic Kingdom Sweden delimitation continental shelf', 'Treaty German Democratic Republic Kingdom Sweden Delimitation Continental Shelf Protocol'])
#
#
# time TF-IDF:  3.4840216636657715
# filename:  African cherry Prunus africana.txt
# ([0.26136350943325737, 0.26136350943325737, 0.26136350943325737, 0.24169329777548118, 0.2367569139886499, 0.2367569139886499, 0.22856962946871404, 0.21680555043843275, 0.20791794573420608, 0.2047998956643287], ['International Energy Charter', 'International Energy Charter', 'International Border Treaty Republic Yemen Kingdom Saudi Arabia', 'International Convention Control Harmful AntiFouling Systems Ships', 'International Tropical Timber Agreement 2006', 'International Tropical Timber Agreement, 1994', 'International Convention Salvage', 'Constitution Center International Forestry Research', 'Constitution Association Natural Rubber Producing Countries', 'Amendment article 124 Rome Statute International Criminal Court'])
#
#
# time TF-IDF:  3.4840216636657715
# filename:  COP411 Cooperation with the European Union.txt
# ([0.370136159632966, 0.33788043166225074, 0.2798868030084667, 0.275793144515598, 0.27489919942391716, 0.27426906929237516, 0.27206895858696434, 0.2692412139222021, 0.2634455526056433, 0.26277999346356595], ['Agreement partnership cooperation Republic Kazakhstan European Union member countries', 'Treaty European Union amended Treaty Lisbon', 'European Outline Convention Transfrontier Cooperation Territorial Communities Authorities', 'Cooperation Agreement European Community Peoples Republic Bangladesh partnership development', 'Protocol Cypriot Republic European Union participation Cyprus European Environment Agency European Environment Information Observation Network N 5III2', 'Agreement Government Russian Federation European Union cooperation sphere science technologies', 'Agreement Government Russian Federation European Space Agency cooperation partnership study outer space peaceful uses thereof', 'Agreement Government Russian Federation European space agency cooperation partnership sphere research management outer space peaceful purposes', 'Protocol 3 European Outline Convention Transfrontier Cooperation Territorial Communities Authorities concerning Euroregional Cooperation Groupings ECGs', 'European Energy Charter'])
#
#
# time TF-IDF:  3.4840216636657715
# filename:  Environmental assessmentinformation system, monitoring and early warning xe2x80x93 Article 12 of the Carpathian Convention.txt
# ([0.2558106726680239, 0.2207578591514624, 0.21322349259430734, 0.20600361457352748, 0.19145060289732163, 0.16707004277286325, 0.16651413209043323, 0.16602504699518145, 0.16214657733123403, 0.16118944563225654], ['Protocol implementation Alpine Convention field mountain forests', 'Protocol implementation Alpine Convention field mountain agriculture', 'Convention European Space Agency', 'Revised Convention Establishment European Organisation Nuclear Research', 'European Landscape Convention', 'Protocol Cypriot Republic European Union participation Cyprus European Environment Agency European Environment Information Observation Network N 5III2', 'International Agreement State Committee Construction, Architecture Housing Policy Ukraine State Committee Construction, Housing Communal Services regarding coordin', 'Convention Establishment European Mediterranean Plant Protection Organisation', 'European Energy Charter', 'Protocol implementation Alpine Convention 1991 field energy'])
#
#
# time TF-IDF:  3.4840216636657715
# filename:  Hexachlorobutadiene.txt
# ([0.40383654692179816, 0.287929170525737, 0.21101989590959133, 0.15034765679248652, 0.1459350886355231, 0.1456120849898811, 0.1456120849898811, 0.13487943539652986, 0.13302590436920822, 0.13302590436920822], ['Stockholm Convention Persistent Organic Pollutants', 'Protocol 1979 Convention LongRange Transboundary Air Pollution Persistent Organic Pollutants', 'Protocol 1979 Convention Longrange Transboundary Air Pollution LongTerm Financing Cooperative Programme Monitoring Evaluation Long Range Transmission Air Pollutants', 'Memorandum Understanding Lebanon Iran environmental field', 'Convention Republic Italy Republic Moldova veterinary health', 'Amendment text annexes II IX Protocol 1979 Convention Long-range Transboundary Air Pollution Abate Acidification, Eutrophication Ground-level Ozone addition new annexes X XI', 'Amendment text annexes II IX Protocol 1979 Convention Long-range Transboundary Air Pollution Abate Acidification, Eutrophication Ground-level Ozone addition new annexes X XI', 'Amendment Paragraph 1, Article XIII Convention Conservation Living Resources Southeast Atlantic', 'Convention Early Notification Nuclear Accident', 'Convention Gouvernement Rxc3xa9publique franxc3xa7aise et Gouvernement Principautxc3xa9 Monaco pour rxc3xa9novation et renforcement sur territoire cette dernixc3'])
#
#
# time TF-IDF:  3.4840216636657715
# filename:  Management of Marine Debris.txt
# ([0.1928915902031179, 0.17728094814889178, 0.17704853866057935, 0.17704853866057935, 0.17489763080095494, 0.17489763080095494, 0.17219547795378448, 0.17067241416245338, 0.16884661236887916, 0.16869292009525758], ['Protocol Protection Marine Environment Black Land Based Sources Activities', 'Kuwait Regional Convention Cooperation Protection Marine Environment Pollution', 'Protocol Protection Marine Environment Pollution LandBased Sources', 'Protocol Protection Black Marine Environment Pollution LandBased Sources', 'Protocol Protection Caspian Pollution LandBased Sources Activities Framework Convention Protection Marine Environment Caspian', 'Protocol Protection Caspian Pollution LandBased Sources Activities Framework Convention Protection Marine Environment Caspian', 'Annex IV Protocol Environmental Protection Antarctic Treaty Prevention marine pollution', 'Amended Nairobi Convention Protection, Management Development Marine Coastal Environment Western Indian Ocean', 'Protocol Protection Marine Coastal Environment Western Indian Ocean LandBased Sources Activities', 'International Convention Prevention Pollution Ships (MARPOL) - Annex V (Optional): Garbage'])
#
#
# time TF-IDF:  3.4840216636657715
# filename:  Outcome of the UNCCD 1st Scientific Conference.pdf.txt
# ([0.19231713833376626, 0.1895820357715276, 0.18630717047116765, 0.18630717047116765, 0.18630717047116765, 0.18332097005201678, 0.18236222104624777, 0.16493222820065934, 0.1608812859695065, 0.16066595735625128], ['Memorandum Understanding scientific technical cooperation field water resources', 'Protocol forth session Joint GreekAlbanian interministerial Committee economic, industrial, technical scientific cooperation Governments Republic Greece', 'Protocol first session GreekArmenian Joint Committee scientific technological cooperation', 'Protocol fifth session Joint GreekItalian Committee scientific technological cooperation', 'Protocol first session Joint GreekEgyptian Committee scientific technological cooperation', 'Agreement Ministry Agriculture Russian Federation Ministry Land Management Slovakia economic, scientific technical cooperation sphere agriculture', 'Technical, Scientific Economic Cooperation Protocol agricultural field Lebanon Turkey', 'Agreement Federal Republic Germany European Economic Community, one hand, Republic Austria, other, cooperation management water resources th', 'Agreement Ministry Agriculture Water Management Uzbekistan Ministry Agriculture Processing Industry Moldova economic, scientific technical cooperation', 'Protocol session Joint GreekYugoslav Commission scientific technological cooperation'])
#
#
# time TF-IDF:  3.4840216636657715
# filename:  Preparation for the followup to the Strategic Plan for Biodiversity 20112020.pdf.txt
# ([0.4515149986946703, 0.4515149986946703, 0.20943474515834165, 0.20943474515834165, 0.20943474515834165, 0.20943474515834165, 0.20943474515834165, 0.20782828917380172, 0.20667952291983374, 0.19286654877434686], ['Nagoya Protocol Access Genetic Resources Fair Equitable Sharing Benefits Arising Utilization Convention Biological Diversity', 'Nagoya Protocol Access Genetic Resources Fair Equitable Sharing Benefits Arising Utilization Convention Biological Diversity', 'Protocol Comprehensive Nuclear TestBan Treaty', 'Protocol Energy', 'Treaty German Democratic Republic Kingdom Sweden Delimitation Continental Shelf Protocol', 'Protocol Mining', 'Protocol Treaty German Democratic Republic Kingdom Sweden delimitation continental shelf', 'Protocol Strategic Environmental Assessment Convention Environmental Impact Assessment Transboundary Context', 'Protocol Pollutant Release Transfer Registers Convention Access Information, PublicParticipation DecisionMaking Access Justice Environmental Matters', 'Protocol conditions relating reciprocal access fishing vessels Parties'])
#
#
# time TF-IDF:  3.4840216636657715
# filename:  Process for aligning national reporting, assessment and review.pdf.txt
# ([0.1709493044881244, 0.16210149911966867, 0.1513937786037711, 0.1513937786037711, 0.1457762680189928, 0.1416797742264063, 0.13869956293704025, 0.13615871116214243, 0.1358489544012051, 0.1358489544012051], ['Cartagena Protocol Biosafety Convention Biological Diversity', 'Protocol Conservation Sustainable Use Biological Landscape Diversity Framework Convention Protection Sustainable Development Carpathians', 'Protocol Sustainable Development Lake Victoria Basin', 'Protocol Sustainable Development Lake Victoria Basin', 'Joint Protocol relating application Vienna Convention Paris Convention', 'Protocol sixth Meeting scientific technological cooperation Joint Committee Hellenic Republic Republic Hungary', 'Protocol Shared Watercourse Systems', 'Agreement constituting National Commission Development Riverbed Rio Pilcomayo', 'Protocol Sustainable Forest Management Framework Convention Protection Sustainable Development Carpathians', 'Protocol Sustainable Forest Management Framework Convention Protection Sustainable Development Carpathians'])
#
#
# time TF-IDF:  3.4840216636657715
# filename:  Pyu Ancient Cities Myanmar C 1444.txt
# ([0.27200747220388566, 0.2681248323066568, 0.2681248323066568, 0.24532890924199902, 0.2293866634086207, 0.2199551273818753, 0.21245087857746564, 0.21245087857746564, 0.20600775661512347, 0.20508493352197044], ['First Session Joint Ministerial Committee Hellenic Republic State Israel', 'Treaty peace State Israel Hashemite Kingdom Jordan', 'Treaty State Border Republic Croatia Bosnia Herzegovina', 'Agreement State Subsoil Board Armenia State Geology Subsoil Management Committee cooperation sphere geological exploration management subsoil', 'Convention concerning Protection World Cultural Natural Heritage', 'Agreement State Committee Nuclear Radiation Safety Ukraine Federal Nuclear Safety Inspectorate Switzerland', 'Convention Conservation Management Vicuna', 'Convention Conservation Management Pollock Central Bering', 'International Agreement State Committee Construction, Architecture Housing Policy Ukraine State Committee Construction, Housing Communal Services regarding coordin', 'Agreement State Committee Energy Saving Ukraine Committee Energetic Efficiency Belarus cooperation sphere energetic efficiency renewable energy'])
#
#
# time TF-IDF:  3.4840216636657715
# filename:  Review of annexes A and B.pdf.txt
# ([0.24942280614114404, 0.24942280614114404, 0.17605857872222452, 0.1530597680003291, 0.14489139767376683, 0.14214726901789487, 0.12947583377911356, 0.12697246405629536, 0.12695031745232008, 0.12533309562174907], ['Minamata Convention Mercury', 'Minamata Convention Mercury', 'Convenio cooperacixc3xb3n proteccixc3xb3n aprovechamiento sostenible aguas cuencas hidrogrxc3xa1ficas hispanoportuguesas, hecho ad referendum Albufeira 30 nov', 'Environmental CooperationAgreement United States America Ukraine 1992', 'United Nations Convention Transnational Organized Crime', 'FisheriesPacific SalmonAgreement United States America Canada extending Annex IV Treaty 28 January 1985, amended', 'Application Safeguards Implementation Article III (1) (4) Treaty Non-Proliferation Nuclear Weapons', 'Fourth ACPEEC Convention', 'Cooperation Programme Syria Ukraine agrarian sciences agricultural products ratified Decree No. 149 5 April 2007', 'Agreement European Community United States America sanitary measures protect public animal health trade live animals animal products'])
#
#
# time TF-IDF:  3.4840216636657715
# filename:  Submission regarding Swaziland.txt
# ([0.19138778064633605, 0.16562312024887021, 0.16426392846455487, 0.16247049654640314, 0.16247049654640314, 0.14243060557628712, 0.13994040493507545, 0.1335139180629708, 0.1335139180629708, 0.1335139180629708], ['Treaty development utilisation water resources Komati River Basin Kingdom Swaziland Government Republic South Africa', 'Convention amend Revised Convention Navigation Rhine', 'Tripartite Interim Agreement Republic Mozambique Republic South Africa Kingdom Swaziland CoOperation Protection Sustainable Utilisation Water', 'Revised Convention Navigation Rhine', 'Additional Protokoll 4 Revised Convention Navigation Rhine', 'Agreement Russian Federation Peoplexc2x92s Republic China regarding Lake Hanka National Natural Preserve', 'Convention Republic Turkey Republic Ukraine concerning cooperation Veterinary field', 'Additional Protocol No6 Revised Convention Navigation Rhine', 'Additional Protocol No5 Revised Convention Navigation Rhine', 'Additional Protocol 2 Revised Convention Navigation Rhine'])

# %% [markdown]
# # Create Sensitivity Analysis Functions
# ## alter input variables, search input parameter grid
# ## score each parameter set, select best set afterwards

# %%
def score_result(filename, output, answers):
    #get the length of the treaties mention + 1 (in case a correct score is one down)
    
    correct_answers = answers[filename]
    len_ans = len(correct_answers)
    if correct_answers[0] == 'None': #if no treaty is mentioned, return 1 minus highest score, to reward a low highest score
        return 1 - output[0][0]
    output_treaty_names = output[1][0:len_ans + 1]
    output_treaty_score = output[0][0:len_ans + 1]
    
    #score the treaties found according to the treaties
    #check if the treaties are maybe not in the right order, so check over all found treaties
    #To find how strong the correlation is, multiply by the score it was given
    #to compare different methods of text search, one has to adjust for the average score -> however, if you run the best attributes again, you can manually see, which methods works better
    
    full_score = 0
    for correct_answer in correct_answers:
        for num, treaty in enumerate(output_treaty_names):
            Search_Query = fuzzyset.FuzzySet()
            Search_Query.add(correct_answer)
            outcome = Search_Query.get(treaty)
            if outcome != None:
                score_1 = outcome[0][0]
                score_2 = output_treaty_score[num]
                full_score += score_1 * score_2
    return full_score
     


def fuzzy_search_sensitivity(step_size = [2,3,4], added_words = [2,3,4]): #loop over the input variables
    overall_score = []
    attributes = []
        
    for step in step_size:
        for added_word in added_words:
            score = 0
            for subfolder in list_of_subfolders: #loop over subfolders
                list_of_files = listdir("Downloads/" + subfolder) #get all files
                counter = 0
                for filename in list_of_files: #go through files in subfolder
                    list_of_outcomes = []



                    if (filename[-3:] == "txt"):  #check if it is a txt document
                        with open("Downloads/" + subfolder + "/" + filename, encoding = "utf8") as f:
                            document_text = f.readlines()


                        #clean the document
                        text = " ".join(document_text) #create long string 
                        text = text.lower()
                        text = re.sub("</?.*?>"," <> ", text) # remove tags
                        text = re.sub("(\\d|\\W)+"," ", text).strip() # remove special characters and digits
                        text = text.split()

                        start_time = time.time()

                        for treaty in treaty_names: 
                            '''
                            VERSION 1: Use fuzzy search
                            As fuzzysearch doesn't work well if the string length differ widely,
                            the code loops over different overlaping parts of the text and saves the highest score
                            '''
                            high_score = 0
                            name_len = len(treaty.split()) #see how long the treaty name is
                            for num  in range(0, len(text) - 2 - name_len, (name_len + added_word) // step): #get the length of the text and get a step size that is according to the name length

                                #use fuzzy search to see the match for the specific part of the text
                                Search_Query = fuzzyset.FuzzySet()
                                Search_Query.add(treaty)
                                outcome = Search_Query.get(" ".join(text[num:num + name_len + added_word]))


                                if outcome != None: #check if the match is None (None will cause error)
                                    if outcome[0][0] > high_score: #check if the current score is larger than the highest score
                                        high_score = outcome[0][0] #update highscore
                            list_of_outcomes.append(high_score)

                        #add outcomes to df, save df
                        print('time FuzzySearch: ', time.time() - start_time)
                        print('filename: ', filename)
                        print('Correct Answers: ', dict_of_correct_answers[filename])
                        print(find_top_X(list_of_outcomes, treaty_names, 10))
                        print()
                        print()
                        score += score_result(filename, find_top_X(list_of_outcomes, treaty_names, 10), dict_of_correct_answers)
                        
            overall_score.append(score)
            attributes.append((step, added_word))
    return overall_score, attributes

                        




def tf_idf_sensitivity(max_features = [10000, 20000, 40000, 60000, 100000], n_gram_range = [(1,1), (1,2), (1,3), (1,4), (2,4)]):#loop over the input parameters
    text_list = []
    name_list = []
    overall_score = []
    attributes = []
    for subfolder in list_of_subfolders: #loop over subfolders
        list_of_files = listdir("Downloads/" + subfolder) #get all files

        for filename in list_of_files: #go through files in subfolder
            
            if (filename[-3:] == "txt"):  #check if it is a txt document
                with open("Downloads/" + subfolder + "/" + filename, encoding = "utf8") as f:
                    document_text = f.readlines()
                    
               
                #clean the document
                text = " ".join(document_text) #create long string 
                text = text.lower()
                text = re.sub("</?.*?>"," <> ", text) # remove tags
                text = re.sub("(\\d|\\W)+"," ", text).strip() # remove special characters and digits
                text = text.split()
                
                
                text_list.append(' '.join(text))
                name_list.append(filename)
                
        start_time = time.time()        
        '''
        VERSION 0: TF-IDF Matrix
        Super Quick, However, not very accurate so far
        '''

        for max_feature in max_features:
            for n_gram in n_gram_range:
                score = 0
            
                X,v = create_tfidf_features(text_list, max_features = max_feature, n_gram_range = n_gram)  
                features = v.get_feature_names()




                similarities = calculate_similarity(X, v, treaty_names)
                search_time = time.time() - start_time
                similarities = np.array(similarities).T
                for num, sims in enumerate(similarities):
                    list_sim = []
                    for sim in sims:
                        list_sim.append(float(sim))
                    print("time TF-IDF: ", search_time)
                    print('Attributes: ', max_feature, n_gram)
                    print('filename: ', name_list[num])
                    print('Correct Answers: ', dict_of_correct_answers[name_list[num]])
                    print(find_top_X(list_sim, treaty_names, 10))
                    score += score_result(name_list[num], find_top_X(list_sim, treaty_names, 10), dict_of_correct_answers)
                    print()
                    print()
                    
                    
                overall_score.append(score)
                attributes.append((max_feature, n_gram))
        return overall_score, attributes
            
            
            
            


def sequence_matcher_sensitivity(): #cannot loop over the input parameters, as there are none
    for subfolder in list_of_subfolders: #loop over subfolders
        list_of_files = listdir("Downloads/" + subfolder) #get all files
        
        overall_score = []
        attributes = []
        score = 0
        for filename in list_of_files: #go through files in subfolder
            
            if (filename[-3:] == "txt"):  #check if it is a txt document
                with open("Downloads/" + subfolder + "/" + filename, encoding = "utf8") as f:
                    document_text = f.readlines()
                    
                
                #clean the document
                text = " ".join(document_text) #create long string 
                text = text.lower()
                text = re.sub("</?.*?>"," <> ", text) # remove tags
                text = re.sub("(\\d|\\W)+"," ", text).strip() # remove special characters and digits
                text = text.split()
                
                start_time = time.time()
                list_of_outcomes = []
                for treaty in treaty_names: 
                    '''
                    VERSION 2: SequenceMatcher
                    Different library - roughly three times faster
                    does not need to loop over 
                    '''
                    
                    
                    s = difflib.SequenceMatcher(None, ''.join(text), treaty)
                    high_score = sum(n for i,j,n in s.get_matching_blocks()) / float(len(treaty))
                    list_of_outcomes.append(high_score)
                    
                #add outcomes to df, save df
                print('time SequenceMatcher: ', time.time() - start_time)
                print('filename: ', filename)
                print(find_top_X(list_of_outcomes, treaty_names, 10))
                print(score_result(filename, find_top_X(list_of_outcomes, treaty_names, 10), dict_of_correct_answers))
                score += score_result(filename, find_top_X(list_of_outcomes, treaty_names, 10), dict_of_correct_answers)
                print()
                print()
            overall_score.append(score)
            attributes.append('Dummy')
            return overall_score, attributes

# %%
'''
Fuzzy Search Sensitivity has a long running time, several hours
PRINTS ALL THE POSSIBLE PARAMETERS IN THE PARAMETER SPACE WITH ASSOCIATED CORRECTNESS VALUE
'''

outcome_tf_idf = tf_idf_sensitivity()
print('TF-IDF Done')

outcome_fuzzy_search = fuzzy_search_sensitivity()
print('Fuzzy Search Done')
print('ENDE')

# %%
print(outcome_tf_idf)
print()
print()
print(outcome_fuzzy_search)

# %% [markdown]
# # Show Results for the Best Parameters

# %%
tf_idf_sensitivity([100000], [(1,1)])

# %%
fuzzy_search_sensitivity([4],[2])

# %%
'''
USE IN FUTURE CLEANING OF TEXTS AND TREATIES
USE FOR ADJUSTING OUTCOME POSSIBLY
'''
def clean_text(text):          
    #clean the document
    text = " ".join(text) #create long string 
    text = text.lower()
    text = re.sub("</?.*?>"," ", text) # remove tags
    text = re.sub('\(.\)| .\)', '', text) #remove a) and (b) mentions
    text = re.sub(r'\w*\d\w*', '', text).strip() #remove mistranslations such as '-' to 'xe23xo0'; basically remove any words that have numbers in it
    text = re.sub("(\\d|\\W)+"," ", text).strip() # remove special characters and digits
    return text
                
            
def clean_treaty_names(name):
    name = [ n for n in name.split() if len(n)> 3]
    name = re.sub(r'\w*\d\w*', '', ' '.join(name)).strip() #remove mistranslations such as '-' to 'xe23xo0'; basically remove any words that have numbers in it
    name = re.sub(r'\w*\.\w*', '', name).strip()
    name = text = re.sub("(\\d|\\W)+"," ", name).strip() # remove special characters and digits
    return name

def adjust_to_name_length(name, score):
    ''' 
    Returns the difference of name length and average length times .01
    Needed, as short treaty names receive higher matches
    '''
    average = 9.73
    return score + ((len(name.split()) - average) * .01)

# %%
list_of_subfolders = ['Train Data/'] #declare subfolder in question

# %%
import matplotlib.pyplot as plt
"""
display histogram of the name length
"""
total = 0
lengts = []
for treaty in treaty_names:
    treaty = clean_treaty_names(treaty)
    total += len(treaty.split())
    lengts.append(len(treaty.split()))
    if len(treaty.split()) <2:
        print(treaty)
print(total/len(treaty_names))
    
    
plt.hist(lengts, bins = 50)
plt.show()

# %%
"""
ADJUST VALUES FOR TREATY NAME LENGTH, AS SHORT TREATIES HAVE HIGHER CHANCE OF HITS THEORETICALLY
CAN ALSO BE ADJUSTED AFTER RUNNING THE ANALYSIS REGULARLY
"""
def fuzzy_search_sensitivity_length_adjusted(step_size = [2,3,4], added_words = [2,3,4]):
    
    overall_score = []
    attributes = []
    start_time = time.time()   
    for step in step_size:
        for added_word in added_words:
            score = 0
            for subfolder in list_of_subfolders: #loop over subfolders
                list_of_files = listdir("Downloads/" + subfolder) #get all files
                counter = 0
                for filename in list_of_files: #go through files in subfolder
                    list_of_outcomes = []



                    if (filename[-3:] == "txt"):  #check if it is a txt document
                        with open("Downloads/" + subfolder + "/" + filename, encoding = "utf8") as f:
                            document_text = f.readlines()


                        #clean the document
                        text = " ".join(document_text) #create long string 
                        text = text.lower()
                        text = re.sub("</?.*?>"," <> ", text) # remove tags
                        text = re.sub("(\\d|\\W)+"," ", text).strip() # remove special characters and digits
                        text = text.split()

                        

                        for treaty in treaty_names: 
                            '''
                            VERSION 1: Use fuzzy search
                            As fuzzysearch doesn't work well if the string length differ widely,
                            the code loops over different overlaping parts of the text and saves the highest score
                            '''
                            high_score = 0
                            name_len = len(treaty.split()) #see how long the treaty name is
                            treaty_specific_step_size = (name_len + added_word) // step
                            if treaty_specific_step_size == 0:
                                treaty_specific_step_size = 1
                            for num  in range(0, len(text) - 2 - name_len, treaty_specific_step_size): #get the length of the text and get a step size that is according to the name length

                                #use fuzzy search to see the match for the specific part of the text
                                Search_Query = fuzzyset.FuzzySet()
                                Search_Query.add(treaty)
                                outcome = Search_Query.get(" ".join(text[num:num + name_len + added_word]))


                                if outcome != None: #check if the match is None (None will cause error)
                                    if outcome[0][0] > high_score: #check if the current score is larger than the highest score
                                        high_score = outcome[0][0] #update highscore
                                        
                            high_score = adjust_to_name_length(treaty, high_score)
                            list_of_outcomes.append(high_score)

                        #add outcomes to df, save df
                        '''
                        print('filename: ', filename)
                        print('Correct Answers: ', dict_of_correct_answers[filename])
                        print(find_top_X(list_of_outcomes, treaty_names, 10))
                        print()
                        print()
                        '''
                        score += score_result(filename, find_top_X(list_of_outcomes, treaty_names, 10), dict_of_correct_answers)
                        
            overall_score.append(score)
            attributes.append((step, added_word))
    print('time FuzzySearch: ', time.time() - start_time)
    return overall_score, attributes

# %%
"""
CLEANING OF TEXTS/NAMES AND ADJUSTING FOR TEXT LENGTHS
"""
def clean_text(text):          
    #clean the document
    text = " ".join(text) #create long string 
    text = text.lower()
    text = re.sub("</?.*?>"," ", text) # remove tags
    text = re.sub('\(.\)| .\)', '', text) #remove a) and (b) mentions
    text = re.sub(r'\w*\d\w*', '', text).strip() #remove mistranslations such as '-' to 'xe23xo0'; basically remove any words that have numbers in it
    text = re.sub("(\\d|\\W)+"," ", text).strip() # remove special characters and digits
    return text
                
            
def clean_treaty_names(name):
    name = [ n for n in name.split() if len(n)> 3]
    name = re.sub(r'\w*\d\w*', '', ' '.join(name)).strip() #remove mistranslations such as '-' to 'xe23xo0'; basically remove any words that have numbers in it
    name = re.sub(r'\w*\.\w*', '', name).strip()
    name = text = re.sub("(\\d|\\W)+"," ", name).strip() # remove special characters and digits
    return name

def adjust_to_name_length(name, score):
    ''' 
    Returns the difference of name length and average length times .01 
    0.01, as 10 is the average, with treaty names ranging between 2 and 25 words (max therefore -/+ .08)
    Needed, as short treaty names receive higher matches
    '''
    average = 9.73
    return score + ((len(name.split()) - average) * .01)

# %% [markdown]
# # Run TF-IDF Analysis with Vocab

# %%
'''
RUN DIFFERENT ANALYSIS WITH ADDED VOCABULARY AS PARAMETER FOR TF-IDF MATRIX
'''
def create_tfidf_features_vocab(corpus, max_features=20000, max_df=0.95, min_df=2, vocab = None, n_gram_range = (1,1)):
    """ Creates a tf-idf matrix for the `corpus` using sklearn. """
    tfidf_vectorizor = TfidfVectorizer(decode_error='replace', strip_accents='unicode', analyzer='word',
                                       stop_words='english', ngram_range=n_gram_range, max_features=max_features,
                                       norm='l2', use_idf=True, smooth_idf=True, sublinear_tf=True, vocabulary = vocab) #or use vocab treaty dict
    X = tfidf_vectorizor.fit_transform(corpus)
    print('tfidf matrix successfully created.')
    return X, tfidf_vectorizor


def calculate_similarity(X, vectorizor, queries, top_k=5):
    """ Vectorizes the `query` via `vectorizor` and calculates the cosine similarity of
    the `query` and `X` (all the documents) and returns the `top_k` similar documents."""

    # Vectorize the query to the same length as documents
    similarities = []
    for query in queries:
        query_vec = vectorizor.transform([query])
        # Compute the cosine similarity between query_vec and all the documents
        cosine_similarities = cosine_similarity(X,query_vec).flatten()
        similarities.append(cosine_similarities)
        
    return similarities

def clean_text(text):          
    #clean the document
    text = " ".join(text) #create long string 
    text = text.lower()
    text = re.sub("</?.*?>"," ", text) # remove tags
    text = re.sub('\(.\)| .\)', '', text) #remove a) and (b) mentions
    text = re.sub(r'\w*\d\w*', '', text).strip() #remove mistranslations such as '-' to 'xe23xo0'; basically remove any words that have numbers in it
    text = re.sub("(\\d|\\W)+"," ", text).strip() # remove special characters and digits
    return text



test_vocab = []
for tret in treaty_names:
    test_vocab.extend(tret.split())
test_vocab = list(set(test_vocab))

# %%
'''
RUN DIFFERENT ANALYSIS WITH ADDED VOCABULARY AS PARAMETER FOR TF-IDF MATRIX
'''

def tf_idf_vocab(max_feature =  100000, n_gram = (1,1), vocab = None, list_of_subfolders = ['Train Data/']):
    text_list = []
    name_list = []
    overall_score = []
    attributes = []
    for subfolder in list_of_subfolders: #loop over subfolders
        list_of_files = listdir("Downloads/" + subfolder) #get all files

        for filename in list_of_files: #go through files in subfolder
            
            if (filename[-3:] == "txt"):  #check if it is a txt document
                with open("Downloads/" + subfolder + "/" + filename, encoding = "utf8") as f:
                    document_text = f.readlines()
                
                    

                text = clean_text(' '.join(document_text))
                
                text_list.append(text)
                name_list.append(filename)
                
                start_time = time.time()        
                '''
                VERSION 0: TF-IDF Matrix
                Super Quick, However, not very accurate so far
                '''

                
                X,v = create_tfidf_features_vocab(text_list, max_features = max_feature, n_gram_range = n_gram, vocab = vocab)  
                features = v.get_feature_names()




                similarities = calculate_similarity(X, v, treaty_names)
                search_time = time.time() - start_time
                similarities = np.array(similarities).T
                score = 0 
                for num, sims in enumerate(similarities):
                    list_sim = []
                    for sim in sims:
                        list_sim.append(float(sim))
                    print("time TF-IDF: ", search_time)
                    print('Attributes: ', max_feature, n_gram)
                    print('filename: ', name_list[num])
                    print('Correct Answers: ', dict_of_correct_answers[name_list[num]])
                    print(find_top_X(list_sim, treaty_names, 10))
                    score += score_result(name_list[num], find_top_X(list_sim, treaty_names, 10), dict_of_correct_answers)
                    print()
                    print()
                    
                    
              
        return score
    
#score_1 = tf_idf_vocab(vocab = test_vocab)
score_2 = tf_idf_vocab()

print(f'score one {score_1} vs score two {score_2}')
